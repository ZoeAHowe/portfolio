# %%
import pandas as pd
import nltk
from nltk.classify import naivebayes

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.classify import NaiveBayesClassifier
from nltk.classify.util import accuracy

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

from collections import Counter

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('CRM_reviews_2.csv')
df.head(5)
# Out:
#    Index        Date                                             Review  \
# 0      1  01/01/2015  Reliable, not bad fast transactions wide range...
# 1      2  01/01/2015  Worried About Fraud But fast transactions wide...
# 2      3  01/01/2015  Helped Me In A Case Of Fraud competitive rates...
# 3      4  01/01/2015  Stable Interest Rate competitive rates easy on...
# 4      5  01/01/2015  Where I Lost My Pin helpful customer service h...
#
#    Rating          Product  District
# 0       5         Mortgage         6
# 1       5  Online Services        44
# 2       5  Online Services        24
# 3       5  Online Services        65
# 4       5  Online Services         2

# %%
online = df[df['Product'] == 'Online Services'].copy()
mortgage = df[df['Product'] == 'Mortgage'].copy()

# %% [markdown]
# ## Online Services Prep

# %%
OS_rating1 = online[online['Rating'] == 1].copy()
OS_rating5 = online[online['Rating'] == 5].copy()

# %%
print('number of 1-star reviews {}'.format(len(OS_rating1)))
print('number of 5-star reviews {}'.format(len(OS_rating5)))
# Out:
# number of 1-star reviews 7093
# number of 5-star reviews 12027

# %%
#Standardise the data so there are the same sized samples of 1 and 5 rated reviews
#Sample appropriate sizes from 1's and 5's 

OS_rating1_sample = OS_rating1.sample(n=6000, random_state=42)
OS_rating5_sample = OS_rating5.sample(n=6000, random_state=42)
print('number of 1-star reviews {}'.format(len(OS_rating1_sample)))
print('number of 5-star reviews {}'.format(len(OS_rating5_sample)))
# Out:
# number of 1-star reviews 6000
# number of 5-star reviews 6000

# %%
#concat your equally sized samples, filter to two columns, reset index
OS_sample_full = pd.concat([OS_rating1_sample, OS_rating5_sample])
OS_sample_full1 = OS_sample_full[['Rating', 'Review']]
OS_sample_full1 = OS_sample_full1.reset_index(drop=True)
OS_sample_full1
# Out:
#        Rating                                             Review
# 0           1  Rude Customer Service complicated to figure ou...
# 1           1  Why!? frustrating soo frustrating!strange erro...
# 2           1  Complicated Online Banking poor interest rates...
# 3           1  To Frustrate Me complicated to figure out bad ...
# 4           1  Soo Frustrating!Strange slow transactions slow...
# ...       ...                                                ...
# 11995       5  Efficient waved fees helpful customer service ...
# 11996       5  Helped Me In A Case Of Fraud friendly staff st...
# 11997       5  Worried About Fraud But friendly staff helpful...
# 11998       5  Secure From Fraud secure from fraud secure fro...
# 11999       5  Easy Online Banking stable interest rate frien...
#
# [12000 rows x 2 columns]

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def remove_stopwords_and_lemmatize(text):
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stop words and lemmatize the tokens
    filtered_tokens = [lemmatizer.lemmatize(word.lower()) for word in tokens if word.lower() not in stop_words and word.isalpha()]
    # Reconstruct the text without stop words
    filtered_text = ' '.join(filtered_tokens)
    return filtered_text

# %%
# Now when you run the function to remove stopwords and lemmatize, it should not give you the warning
OS_sample_full1['Review'] = OS_sample_full1['Review'].apply(remove_stopwords_and_lemmatize)
#tokenise each
OS_sample_full1['Tokens'] = OS_sample_full1['Review'].apply(word_tokenize)

# %%
OS_sample_full1.Tokens[1]
# Out:
# ['frustrating',
#  'soo',
#  'frustrating',
#  'strange',
#  'error',
#  'kept',
#  'cropping',
#  'poor',
#  'interest',
#  'rate',
#  'additional',
#  'charge',
#  'frustrating']

# %%
OS_sample_full1
# Out:
#        Rating                                             Review  \
# 0           1  rude customer service complicated figure soo f...
# 1           1  frustrating soo frustrating strange error kept...
# 2           1  complicated online banking poor interest rate ...
# 3           1  frustrate complicated figure bad advice error ...
# 4           1  soo frustrating strange slow transaction slow ...
# ...       ...                                                ...
# 11995       5  efficient waved fee helpful customer service f...
# 11996       5  helped case fraud friendly staff stable intere...
# 11997       5  worried fraud friendly staff helpful customer ...
# 11998       5  secure fraud secure fraud secure fraud fast tr...
# 11999       5  easy online banking stable interest rate frien...
#
#                                                   Tokens
# 0      [rude, customer, service, complicated, figure,...
# 1      [frustrating, soo, frustrating, strange, error...
# 2      [complicated, online, banking, poor, interest,...
# 3      [frustrate, complicated, figure, bad, advice, ...
# 4      [soo, frustrating, strange, slow, transaction,...
# ...                                                  ...
# 11995  [efficient, waved, fee, helpful, customer, ser...
# 11996  [helped, case, fraud, friendly, staff, stable,...
# 11997  [worried, fraud, friendly, staff, helpful, cus...
# 11998  [secure, fraud, secure, fraud, secure, fraud, ...
# 11999  [easy, online, banking, stable, interest, rate...
#
# [12000 rows x 3 columns]

# %% [markdown]
# ## Mortgage Prep

# %%
mort_rating1 = mortgage[mortgage['Rating'] == 1].copy()
mort_rating5 = mortgage[mortgage['Rating'] == 5].copy()

# %%
print('number of 1-star reviews {}'.format(len(mort_rating1)))
print('number of 5-star reviews {}'.format(len(mort_rating5)))
# Out:
# number of 1-star reviews 1027
# number of 5-star reviews 806

# %%
#Standardise the data so there are the same sized samples of 1 and 5 rated reviews
#Sample appropriate sizes from 1's and 5's 

mort_rating1_sample = mort_rating1.sample(n=750, random_state=42)
mort_rating5_sample = mort_rating5.sample(n=750, random_state=42)
print('number of 1-star reviews {}'.format(len(mort_rating1_sample)))
print('number of 5-star reviews {}'.format(len(mort_rating5_sample)))
# Out:
# number of 1-star reviews 750
# number of 5-star reviews 750

# %%
#concat your equally sized samples, filter to two columns, reset index
mort_sample_full = pd.concat([mort_rating1_sample, mort_rating5_sample])
mort_sample_full1 = mort_sample_full[['Rating', 'Review']]
mort_sample_full1 = mort_sample_full1.reset_index(drop=True)
mort_sample_full1
# Out:
#       Rating                                             Review
# 0          1  Insecure additional charges limited services i...
# 1          1  What Happened what happened fees rude customer...
# 2          1  Poor Interest Rates rude customer service addi...
# 3          1  What Happened what happened rude customer serv...
# 4          1  High Fees what happened i hope youre proud of ...
# ...      ...                                                ...
# 1495       5       Stressed At First Tho Thank you! Thank you!.
# 1496       5  Not Bad wide range of services Thank you! help...
# 1497       5  Thank You! very good with ease not bad excelle...
# 1498       5  Stressed At First Tho worried but got really h...
# 1499       5        Stressed At First Tho waved fees with ease.
#
# [1500 rows x 2 columns]

# %%
# Now when you run the function to remove stopwords and lemmatize, it should not give you the warning
mort_sample_full1['Review'] = mort_sample_full1['Review'].apply(remove_stopwords_and_lemmatize)
#tokenise each
mort_sample_full1['Tokens'] = mort_sample_full1['Review'].apply(word_tokenize)

# %%
mort_sample_full1.Tokens[1]
# Out:
# ['happened', 'happened', 'fee', 'rude', 'customer', 'service']

# %%
mort_sample_full1
# Out:
#       Rating                                             Review  \
# 0          1  insecure additional charge limited service hop...
# 1          1        happened happened fee rude customer service
# 2          1  poor interest rate rude customer service addit...
# 3          1  happened happened rude customer service bad fi...
# 4          1  high fee happened hope youre proud rude custom...
# ...      ...                                                ...
# 1495       5                     stressed first tho thank thank
# 1496       5  bad wide range service thank helpful customer ...
# 1497       5     thank good ease bad excellent financial advice
# 1498       5  stressed first tho worried got really helpful ...
# 1499       5                  stressed first tho waved fee ease
#
#                                                  Tokens
# 0     [insecure, additional, charge, limited, servic...
# 1     [happened, happened, fee, rude, customer, serv...
# 2     [poor, interest, rate, rude, customer, service...
# 3     [happened, happened, rude, customer, service, ...
# 4     [high, fee, happened, hope, youre, proud, rude...
# ...                                                 ...
# 1495               [stressed, first, tho, thank, thank]
# 1496  [bad, wide, range, service, thank, helpful, cu...
# 1497  [thank, good, ease, bad, excellent, financial,...
# 1498  [stressed, first, tho, worried, got, really, h...
# 1499           [stressed, first, tho, waved, fee, ease]
#
# [1500 rows x 3 columns]

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Online Services

# %%
# Prepare the data
def document_features(token_list):
    return {token: True for token in token_list}

OS_data = [(document_features(tokens), str(score)) for tokens, score in zip(OS_sample_full1['Tokens'], OS_sample_full1['Rating'])]

# %%
OS_data
# Out:
# [({'rude': True,
#    'customer': True,
#    'service': True,
#    'complicated': True,
#    'figure': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'slow': True,
#    'transaction': True,
#    'error': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'frustrating': True,
#    'soo': True,
#    'strange': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'complicated': True,
#    'online': True,
#    'banking': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'frustrate': True},
#   '1'),
#  ({'frustrate': True,
#    'complicated': True,
#    'figure': True,
#    'bad': True,
#    'advice': True,
#    'error': True,
#    'kept': True,
#    'cropping': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'slow': True,
#    'transaction': True,
#    'complicated': True,
#    'figure': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'error': True},
#   '1'),
#  ({'great': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'frustrate': True,
#    'error': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'happened': True,
#    'bank': True,
#    'complicated': True,
#    'figure': True,
#    'worst': True,
#    'frustrating': True,
#    'online': True,
#    'banking': True},
#   '1'),
#  ({'complicated': True,
#    'online': True,
#    'banking': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'great': True,
#    'happened': True,
#    'bank': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'figure': True},
#   '1'),
#  ({'error': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'complicated': True,
#    'online': True,
#    'banking': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'bad': True,
#    'advice': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'happened': True,
#    'bank': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'frustrate': True,
#    'figure': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'bad': True,
#    'advice': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'happened': True,
#    'bank': True,
#    'frustrate': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True},
#   '1'),
#  ({'frustrate': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'bad': True,
#    'advice': True,
#    'rude': True,
#    'customer': True,
#    'service': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'additional': True,
#    'charge': True,
#    'worst': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'complicated': True,
#    'figure': True},
#   '1'),
#  ({'error': True,
#    'frustrating': True,
#    'limited': True,
#    'service': True,
#    'worst': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'great': True,
#    'frustrating': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'error': True,
#    'slow': True,
#    'transaction': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'complicated': True,
#    'online': True,
#    'banking': True,
#    'error': True,
#    'kept': True,
#    'cropping': True},
#   '1'),
#  ({'worst': True,
#    'error': True,
#    'frustrate': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'error': True},
#   '1'),
#  ({'frustrating': True,
#    'slow': True,
#    'transaction': True,
#    'great': True,
#    'error': True},
#   '1'),
#  ({'complicated': True,
#    'online': True,
#    'banking': True,
#    'figure': True,
#    'worst': True,
#    'error': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'worst': True,
#    'complicated': True,
#    'figure': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'error': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'frustrate': True,
#    'error': True,
#    'limited': True,
#    'service': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'great': True,
#    'limited': True,
#    'service': True,
#    'online': True,
#    'banking': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'happened': True,
#    'bank': True,
#    'frustrate': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'worst': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'great': True,
#    'frustrate': True,
#    'limited': True,
#    'service': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'bad': True,
#    'advice': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'frustrate': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True},
#   '1'),
#  ({'error': True,
#    'kept': True,
#    'cropping': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'happened': True,
#    'bank': True,
#    'figure': True,
#    'frustrate': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'happened': True,
#    'bank': True,
#    'bad': True,
#    'advice': True,
#    'online': True,
#    'banking': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'bad': True,
#    'advice': True,
#    'additional': True,
#    'charge': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'additional': True,
#    'charge': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'complicated': True,
#    'online': True,
#    'banking': True,
#    'limited': True,
#    'service': True,
#    'frustrating': True,
#    'additional': True,
#    'charge': True,
#    'bad': True,
#    'advice': True,
#    'great': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'worst': True,
#    'great': True},
#   '1'),
#  ({'worst': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'complicated': True,
#    'figure': True},
#   '1'),
#  ({'error': True,
#    'kept': True,
#    'cropping': True,
#    'frustrating': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'limited': True,
#    'service': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'error': True,
#    'great': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'slow': True,
#    'transaction': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'worst': True,
#    'additional': True,
#    'charge': True,
#    'happened': True,
#    'bank': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'happened': True,
#    'bank': True,
#    'complicated': True,
#    'figure': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True},
#   '1'),
#  ({'great': True,
#    'complicated': True,
#    'figure': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'frustrate': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'error': True},
#   '1'),
#  ({'error': True,
#    'kept': True,
#    'cropping': True,
#    'bad': True,
#    'advice': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'limited': True,
#    'service': True,
#    'worst': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'happened': True,
#    'bank': True,
#    'frustrating': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'happened': True,
#    'bank': True,
#    'additional': True,
#    'charge': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'complicated': True,
#    'figure': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'happened': True,
#    'bank': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'figure': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'bad': True,
#    'advice': True,
#    'limited': True,
#    'great': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'error': True,
#    'great': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'bad': True,
#    'advice': True,
#    'figure': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'error': True,
#    'kept': True,
#    'cropping': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'worst': True},
#   '1'),
#  ({'happened': True,
#    'bank': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'online': True,
#    'banking': True,
#    'additional': True,
#    'charge': True,
#    'great': True},
#   '1'),
#  ({'error': True,
#    'kept': True,
#    'cropping': True,
#    'frustrate': True,
#    'happened': True,
#    'bank': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'frustrating': True,
#    'frustrate': True,
#    'additional': True,
#    'charge': True,
#    'worst': True},
#   '1'),
#  ({'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'error': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'frustrate': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'complicated': True,
#    'figure': True,
#    'great': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'frustrating': True,
#    'soo': True,
#    'strange': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'great': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'happened': True,
#    'bank': True,
#    'complicated': True,
#    'figure': True,
#    'great': True,
#    'bad': True,
#    'advice': True,
#    'frustrate': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'bad': True,
#    'advice': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'additional': True,
#    'charge': True,
#    'limited': True,
#    'service': True,
#    'bad': True,
#    'advice': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'frustrate': True},
#   '1'),
#  ({'happened': True,
#    'bank': True,
#    'worst': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'complicated': True,
#    'figure': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'additional': True,
#    'charge': True,
#    'frustrating': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'figure': True,
#    'great': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'limited': True,
#    'service': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'complicated': True,
#    'figure': True,
#    'frustrate': True,
#    'worst': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'error': True,
#    'kept': True,
#    'cropping': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'limited': True,
#    'service': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'error': True,
#    'kept': True,
#    'cropping': True,
#    'happened': True,
#    'bank': True,
#    'slow': True,
#    'transaction': True,
#    'frustrate': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'happened': True,
#    'bank': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'great': True,
#    'complicated': True,
#    'figure': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'complicated': True,
#    'online': True,
#    'banking': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'frustrate': True,
#    'worst': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'happened': True,
#    'bank': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'additional': True,
#    'charge': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'frustrating': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'great': True,
#    'bad': True,
#    'advice': True},
#   '1'),
#  ({'frustrating': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'additional': True,
#    'charge': True,
#    'limited': True,
#    'complicated': True,
#    'online': True,
#    'banking': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'online': True,
#    'banking': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'bad': True,
#    'advice': True,
#    'error': True,
#    'happened': True,
#    'bank': True,
#    'great': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'great': True,
#    'happened': True,
#    'bank': True,
#    'error': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'limited': True,
#    'service': True,
#    'worst': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'great': True,
#    'worst': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'frustrate': True},
#   '1'),
#  ({'frustrating': True,
#    'limited': True,
#    'service': True,
#    'complicated': True,
#    'figure': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'frustrate': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'great': True,
#    'slow': True,
#    'transaction': True,
#    'complicated': True,
#    'figure': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'online': True,
#    'banking': True,
#    'limited': True},
#   '1'),
#  ({'slow': True, 'transaction': True, 'great': True, 'worst': True}, '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'worst': True,
#    'frustrate': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'slow': True,
#    'transaction': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'frustrate': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'happened': True,
#    'bank': True,
#    'great': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'worst': True},
#   '1'),
#  ({'frustrating': True,
#    'soo': True,
#    'strange': True,
#    'additional': True,
#    'charge': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'frustrate': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'complicated': True,
#    'figure': True,
#    'worst': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'limited': True,
#    'service': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'frustrate': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'limited': True,
#    'service': True,
#    'great': True,
#    'frustrating': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'rude': True,
#    'customer': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'frustrate': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'great': True,
#    'worst': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'error': True,
#    'limited': True,
#    'service': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'worst': True,
#    'bad': True,
#    'advice': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'complicated': True,
#    'figure': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'worst': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'online': True,
#    'banking': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'additional': True,
#    'charge': True,
#    'error': True,
#    'kept': True,
#    'cropping': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'happened': True,
#    'bank': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True},
#   '1'),
#  ({'worst': True,
#    'error': True,
#    'great': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'frustrating': True,
#    'error': True},
#   '1'),
#  ({'frustrate': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'bad': True,
#    'advice': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'worst': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'bad': True,
#    'advice': True,
#    'happened': True,
#    'bank': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True},
#   '1'),
#  ({'error': True,
#    'worst': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'rude': True,
#    'customer': True,
#    'service': True},
#   '1'),
#  ({'worst': True,
#    'additional': True,
#    'charge': True,
#    'error': True,
#    'kept': True,
#    'cropping': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'great': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True},
#   '1'),
#  ({'error': True,
#    'kept': True,
#    'cropping': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True},
#   '1'),
#  ({'worst': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'great': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'figure': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'happened': True,
#    'bank': True,
#    'worst': True,
#    'online': True,
#    'banking': True},
#   '1'),
#  ({'worst': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'frustrating': True,
#    'bad': True,
#    'advice': True,
#    'frustrate': True},
#   '1'),
#  ({'error': True,
#    'limited': True,
#    'service': True,
#    'rude': True,
#    'customer': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'complicated': True,
#    'online': True,
#    'banking': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True},
#   '1'),
#  ({'worst': True,
#    'great': True,
#    'happened': True,
#    'bank': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'additional': True,
#    'charge': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'error': True,
#    'happened': True,
#    'bank': True,
#    'great': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'frustrate': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'frustrating': True,
#    'bad': True,
#    'advice': True,
#    'happened': True,
#    'bank': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'worst': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'additional': True,
#    'charge': True,
#    'frustrate': True},
#   '1'),
#  ({'frustrating': True, 'additional': True, 'charge': True, 'great': True},
#   '1'),
#  ({'long': True, 'wait': True, 'time': True, 'bad': True, 'advice': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'additional': True,
#    'charge': True,
#    'error': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'great': True, 'frustrate': True}, '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'happened': True,
#    'bank': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'figure': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'frustrating': True,
#    'complicated': True,
#    'figure': True,
#    'limited': True,
#    'service': True,
#    'online': True,
#    'banking': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'happened': True,
#    'bank': True},
#   '1'),
#  ({'error': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'limited': True,
#    'service': True,
#    'frustrating': True,
#    'soo': True,
#    'strange': True},
#   '1'),
#  ({'complicated': True,
#    'online': True,
#    'banking': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'worst': True,
#    'frustrating': True,
#    'error': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'additional': True,
#    'charge': True,
#    'great': True,
#    'frustrate': True,
#    'frustrating': True},
#   '1'),
#  ({'frustrate': True,
#    'frustrating': True,
#    'bad': True,
#    'advice': True,
#    'rude': True,
#    'customer': True,
#    'service': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'limited': True,
#    'service': True,
#    'frustrate': True,
#    'worst': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'additional': True,
#    'charge': True,
#    'error': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'happened': True,
#    'bank': True,
#    'limited': True,
#    'service': True,
#    'complicated': True,
#    'figure': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'frustrate': True,
#    'bad': True,
#    'advice': True},
#   '1'),
#  ({'frustrate': True,
#    'great': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True},
#   '1'),
#  ({'frustrate': True,
#    'complicated': True,
#    'figure': True,
#    'error': True,
#    'slow': True,
#    'transaction': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'great': True},
#   '1'),
#  ({'complicated': True,
#    'online': True,
#    'banking': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'worst': True,
#    'figure': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'error': True,
#    'slow': True,
#    'transaction': True,
#    'additional': True,
#    'charge': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'complicated': True,
#    'figure': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'bad': True,
#    'advice': True,
#    'worst': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'worst': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'additional': True,
#    'charge': True,
#    'error': True,
#    'kept': True,
#    'cropping': True},
#   '1'),
#  ({'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'frustrate': True,
#    'bad': True,
#    'advice': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'frustrating': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'error': True,
#    'frustrate': True},
#   '1'),
#  ({'error': True,
#    'kept': True,
#    'cropping': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'bad': True,
#    'advice': True,
#    'slow': True,
#    'transaction': True,
#    'great': True,
#    'frustrate': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'frustrating': True,
#    'limited': True,
#    'service': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'great': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'frustrating': True,
#    'complicated': True,
#    'figure': True,
#    'bad': True,
#    'advice': True,
#    'additional': True,
#    'charge': True,
#    'soo': True,
#    'strange': True},
#   '1'),
#  ({'complicated': True,
#    'online': True,
#    'banking': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'limited': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'happened': True,
#    'bank': True,
#    'error': True,
#    'kept': True,
#    'cropping': True},
#   '1'),
#  ({'complicated': True,
#    'online': True,
#    'banking': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'bad': True,
#    'advice': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'slow': True,
#    'transaction': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'bad': True,
#    'advice': True,
#    'frustrate': True},
#   '1'),
#  ({'worst': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'frustrating': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'happened': True,
#    'bank': True,
#    'frustrate': True,
#    'bad': True,
#    'advice': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'frustrating': True,
#    'happened': True,
#    'bank': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'worst': True,
#    'happened': True,
#    'bank': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'additional': True,
#    'charge': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'rude': True,
#    'customer': True,
#    'service': True},
#   '1'),
#  ({'frustrate': True,
#    'complicated': True,
#    'figure': True,
#    'online': True,
#    'banking': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'worst': True,
#    'frustrating': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'frustrate': True,
#    'additional': True,
#    'charge': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'great': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'bad': True,
#    'advice': True},
#   '1'),
#  ({'error': True,
#    'great': True,
#    'rude': True,
#    'customer': True,
#    'service': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'complicated': True,
#    'figure': True,
#    'bad': True,
#    'advice': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'limited': True,
#    'service': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'bad': True,
#    'advice': True,
#    'great': True,
#    'error': True,
#    'happened': True,
#    'bank': True,
#    'frustrate': True},
#   '1'),
#  ({'worst': True,
#    'limited': True,
#    'service': True,
#    'frustrate': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'bad': True,
#    'advice': True},
#   '1'),
#  ({'worst': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'great': True,
#    'frustrate': True},
#   '1'),
#  ({'error': True,
#    'kept': True,
#    'cropping': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'great': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'limited': True,
#    'service': True,
#    'frustrate': True,
#    'bad': True,
#    'advice': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'bad': True,
#    'advice': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'limited': True,
#    'service': True,
#    'happened': True,
#    'bank': True,
#    'complicated': True,
#    'figure': True,
#    'online': True,
#    'banking': True,
#    'great': True},
#   '1'),
#  ({'error': True,
#    'kept': True,
#    'cropping': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'frustrating': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'limited': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'frustrate': True,
#    'bad': True,
#    'advice': True,
#    'error': True,
#    'kept': True,
#    'cropping': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'limited': True,
#    'service': True,
#    'figure': True},
#   '1'),
#  ({'frustrating': True,
#    'complicated': True,
#    'figure': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'slow': True,
#    'transaction': True,
#    'limited': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'error': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'great': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'frustrate': True,
#    'happened': True,
#    'bank': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True},
#   '1'),
#  ({'complicated': True,
#    'online': True,
#    'banking': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'happened': True,
#    'bank': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'bad': True,
#    'advice': True},
#   '1'),
#  ({'happened': True,
#    'bank': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'error': True},
#   '1'),
#  ({'frustrating': True,
#    'complicated': True,
#    'figure': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'error': True,
#    'rude': True,
#    'customer': True,
#    'service': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'great': True,
#    'limited': True,
#    'service': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'limited': True,
#    'service': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'frustrate': True},
#   '1'),
#  ({'happened': True,
#    'bank': True,
#    'limited': True,
#    'service': True,
#    'great': True,
#    'error': True,
#    'worst': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'happened': True,
#    'bank': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'great': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'error': True,
#    'kept': True,
#    'cropping': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'great': True},
#   '1'),
#  ({'error': True,
#    'kept': True,
#    'cropping': True,
#    'additional': True,
#    'charge': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'happened': True,
#    'bank': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'worst': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'bad': True,
#    'advice': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'limited': True,
#    'complicated': True,
#    'figure': True,
#    'worst': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'online': True,
#    'banking': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'complicated': True,
#    'online': True,
#    'banking': True,
#    'happened': True,
#    'bank': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'limited': True,
#    'service': True,
#    'rude': True,
#    'customer': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'error': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'bad': True,
#    'advice': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'great': True,
#    'frustrating': True,
#    'worst': True,
#    'happened': True,
#    'bank': True,
#    'limited': True,
#    'service': True,
#    'complicated': True,
#    'figure': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'happened': True,
#    'bank': True,
#    'complicated': True,
#    'figure': True},
#   '1'),
#  ({'complicated': True,
#    'online': True,
#    'banking': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'additional': True,
#    'charge': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'frustrating': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'error': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'error': True,
#    'bad': True,
#    'advice': True,
#    'kept': True,
#    'cropping': True,
#    'complicated': True,
#    'figure': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'complicated': True,
#    'figure': True,
#    'worst': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'happened': True,
#    'bank': True,
#    'bad': True,
#    'advice': True,
#    'great': True},
#   '1'),
#  ({'error': True,
#    'bad': True,
#    'advice': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'happened': True, 'bank': True, 'frustrating': True, 'frustrate': True},
#   '1'),
#  ({'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'complicated': True,
#    'figure': True,
#    'slow': True,
#    'transaction': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'great': True,
#    'limited': True,
#    'service': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'limited': True,
#    'service': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'error': True,
#    'kept': True,
#    'cropping': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'additional': True,
#    'charge': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'frustrate': True,
#    'happened': True,
#    'bank': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'additional': True,
#    'charge': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'slow': True,
#    'transaction': True,
#    'frustrate': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'great': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'limited': True,
#    'service': True,
#    'figure': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'happened': True,
#    'bank': True,
#    'error': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'frustrate': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'happened': True,
#    'bank': True,
#    'worst': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'worst': True,
#    'bad': True,
#    'advice': True,
#    'frustrate': True,
#    'frustrating': True},
#   '1'),
#  ({'worst': True,
#    'additional': True,
#    'charge': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'great': True},
#   '1'),
#  ({'additional': True, 'charge': True, 'worst': True}, '1'),
#  ({'error': True,
#    'kept': True,
#    'cropping': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'happened': True,
#    'bank': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'error': True,
#    'limited': True,
#    'service': True,
#    'happened': True,
#    'bank': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'complicated': True,
#    'figure': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'limited': True,
#    'frustrating': True,
#    'error': True,
#    'worst': True,
#    'bad': True,
#    'advice': True},
#   '1'),
#  ({'frustrate': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'happened': True,
#    'bank': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'bad': True, 'advice': True, 'additional': True, 'charge': True}, '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'frustrating': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'additional': True,
#    'charge': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'happened': True,
#    'bank': True,
#    'bad': True,
#    'advice': True,
#    'worst': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'frustrate': True,
#    'additional': True,
#    'charge': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'complicated': True,
#    'online': True,
#    'banking': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'complicated': True,
#    'figure': True},
#   '1'),
#  ({'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'slow': True,
#    'transaction': True,
#    'frustrating': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'error': True,
#    'kept': True,
#    'cropping': True},
#   '1'),
#  ({'frustrating': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'slow': True,
#    'transaction': True,
#    'complicated': True,
#    'figure': True},
#   '1'),
#  ({'frustrating': True, 'rude': True, 'customer': True, 'service': True}, '1'),
#  ({'frustrating': True,
#    'happened': True,
#    'bank': True,
#    'frustrate': True,
#    'error': True,
#    'bad': True,
#    'advice': True},
#   '1'),
#  ({'frustrate': True, 'happened': True, 'bank': True}, '1'),
#  ({'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'frustrating': True,
#    'complicated': True,
#    'online': True,
#    'banking': True},
#   '1'),
#  ({'happened': True,
#    'bank': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'bad': True,
#    'advice': True,
#    'complicated': True,
#    'figure': True,
#    'online': True,
#    'banking': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'happened': True,
#    'bank': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'worst': True}, '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'bad': True,
#    'advice': True,
#    'figure': True},
#   '1'),
#  ({'frustrate': True,
#    'error': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'worst': True,
#    'complicated': True,
#    'figure': True},
#   '1'),
#  ({'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'bad': True,
#    'advice': True,
#    'additional': True,
#    'charge': True,
#    'great': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'great': True,
#    'complicated': True,
#    'figure': True,
#    'happened': True,
#    'bank': True,
#    'online': True,
#    'banking': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'great': True},
#   '1'),
#  ({'worst': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'complicated': True,
#    'figure': True},
#   '1'),
#  ({'frustrating': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'great': True,
#    'complicated': True,
#    'figure': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'limited': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'rude': True,
#    'customer': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'complicated': True,
#    'online': True,
#    'banking': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'additional': True,
#    'charge': True,
#    'great': True,
#    'frustrating': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'frustrate': True,
#    'great': True,
#    'error': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'happened': True,
#    'bank': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'frustrating': True,
#    'worst': True,
#    'soo': True,
#    'strange': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'complicated': True,
#    'figure': True,
#    'worst': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'worst': True,
#    'poor': True,
#    'interest': True,
# ...
#    'banking': True,
#    'slow': True,
#    'transaction': True,
#    'limited': True,
#    'service': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'worst': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'error': True,
#    'slow': True,
#    'transaction': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'frustrate': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'happened': True,
#    'bank': True,
#    'frustrate': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'bad': True,
#    'advice': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'frustrating': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'frustrate': True},
#   '1'),
#  ({'happened': True,
#    'bank': True,
#    'error': True,
#    'rude': True,
#    'customer': True,
#    'service': True},
#   '1'),
#  ({'happened': True,
#    'bank': True,
#    'frustrating': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'frustrate': True,
#    'bad': True,
#    'advice': True,
#    'worst': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'error': True,
#    'frustrate': True,
#    'complicated': True,
#    'online': True,
#    'banking': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'great': True,
#    'additional': True,
#    'charge': True,
#    'slow': True,
#    'transaction': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'frustrate': True,
#    'frustrating': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'bad': True,
#    'advice': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'limited': True,
#    'happened': True,
#    'bank': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'bad': True,
#    'advice': True,
#    'frustrate': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'slow': True,
#    'transaction': True,
#    'limited': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'happened': True,
#    'bank': True,
#    'frustrating': True,
#    'bad': True,
#    'advice': True,
#    'slow': True,
#    'transaction': True,
#    'soo': True,
#    'strange': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'slow': True,
#    'transaction': True,
#    'complicated': True,
#    'online': True,
#    'banking': True},
#   '1'),
#  ({'frustrate': True,
#    'complicated': True,
#    'figure': True,
#    'happened': True,
#    'bank': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'bad': True,
#    'advice': True,
#    'frustrating': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'additional': True,
#    'charge': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'great': True,
#    'frustrate': True,
#    'complicated': True,
#    'figure': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'frustrate': True,
#    'worst': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'limited': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'great': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'limited': True,
#    'frustrate': True,
#    'frustrating': True},
#   '1'),
#  ({'happened': True,
#    'bank': True,
#    'slow': True,
#    'transaction': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'complicated': True,
#    'online': True,
#    'banking': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'bad': True,
#    'advice': True,
#    'figure': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'additional': True,
#    'charge': True,
#    'error': True,
#    'worst': True,
#    'rude': True,
#    'customer': True,
#    'service': True},
#   '1'),
#  ({'error': True,
#    'complicated': True,
#    'figure': True,
#    'additional': True,
#    'charge': True,
#    'limited': True,
#    'service': True,
#    'great': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'limited': True,
#    'service': True,
#    'frustrate': True,
#    'complicated': True,
#    'online': True,
#    'banking': True},
#   '1'),
#  ({'great': True,
#    'frustrating': True,
#    'worst': True,
#    'slow': True,
#    'transaction': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'great': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'bad': True,
#    'advice': True},
#   '1'),
#  ({'frustrate': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'frustrating': True,
#    'complicated': True,
#    'figure': True,
#    'happened': True,
#    'bank': True},
#   '1'),
#  ({'worst': True,
#    'great': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'limited': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'happened': True,
#    'bank': True,
#    'complicated': True,
#    'figure': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'online': True,
#    'banking': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'worst': True,
#    'limited': True},
#   '1'),
#  ({'frustrating': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'bad': True,
#    'advice': True},
#   '1'),
#  ({'great': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'frustrate': True,
#    'happened': True,
#    'bank': True,
#    'complicated': True,
#    'figure': True},
#   '1'),
#  ({'frustrating': True,
#    'error': True,
#    'slow': True,
#    'transaction': True,
#    'worst': True},
#   '1'),
#  ({'complicated': True,
#    'online': True,
#    'banking': True,
#    'additional': True,
#    'charge': True,
#    'worst': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'slow': True,
#    'transaction': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'limited': True,
#    'service': True,
#    'complicated': True,
#    'figure': True,
#    'frustrate': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'bad': True,
#    'advice': True,
#    'frustrating': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'complicated': True,
#    'figure': True,
#    'worst': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'great': True,
#    'frustrate': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'happened': True,
#    'bank': True,
#    'slow': True,
#    'transaction': True,
#    'worst': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'frustrate': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'additional': True,
#    'charge': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'error': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'worst': True,
#    'bad': True,
#    'advice': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'error': True,
#    'bad': True,
#    'advice': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'frustrate': True,
#    'great': True,
#    'complicated': True,
#    'figure': True,
#    'error': True,
#    'kept': True,
#    'cropping': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'frustrating': True,
#    'happened': True,
#    'bank': True},
#   '1'),
#  ({'complicated': True,
#    'online': True,
#    'banking': True,
#    'limited': True,
#    'service': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'rude': True,
#    'customer': True},
#   '1'),
#  ({'complicated': True,
#    'online': True,
#    'banking': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'happened': True,
#    'bank': True,
#    'frustrate': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'additional': True,
#    'charge': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'frustrating': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'happened': True,
#    'bank': True},
#   '1'),
#  ({'frustrating': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'complicated': True,
#    'figure': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'error': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'worst': True,
#    'slow': True,
#    'transaction': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'error': True,
#    'kept': True,
#    'cropping': True},
#   '1'),
#  ({'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'happened': True,
#    'bank': True,
#    'error': True},
#   '1'),
#  ({'frustrate': True,
#    'great': True,
#    'error': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'error': True,
#    'kept': True,
#    'cropping': True,
#    'worst': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'happened': True,
#    'bank': True,
#    'bad': True,
#    'advice': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'additional': True,
#    'charge': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'great': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'great': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'additional': True,
#    'charge': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'bad': True,
#    'advice': True,
#    'happened': True,
#    'bank': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'slow': True,
#    'transaction': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'frustrating': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'complicated': True,
#    'figure': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'frustrating': True,
#    'complicated': True,
#    'figure': True,
#    'bad': True,
#    'advice': True,
#    'error': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'great': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'frustrate': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'worst': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True},
#   '1'),
#  ({'complicated': True,
#    'online': True,
#    'banking': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'worst': True,
#    'figure': True},
#   '1'),
#  ({'worst': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'complicated': True,
#    'online': True,
#    'banking': True},
#   '1'),
#  ({'great': True,
#    'frustrate': True,
#    'complicated': True,
#    'figure': True,
#    'error': True,
#    'kept': True,
#    'cropping': True},
#   '1'),
#  ({'error': True,
#    'kept': True,
#    'cropping': True,
#    'additional': True,
#    'charge': True,
#    'worst': True},
#   '1'),
#  ({'great': True,
#    'frustrating': True,
#    'limited': True,
#    'service': True,
#    'rude': True,
#    'customer': True,
#    'worst': True},
#   '1'),
#  ({'error': True,
#    'kept': True,
#    'cropping': True,
#    'worst': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'complicated': True,
#    'online': True,
#    'banking': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'slow': True,
#    'transaction': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'great': True,
#    'worst': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True,
#    'error': True,
#    'slow': True,
#    'transaction': True,
#    'complicated': True,
#    'figure': True,
#    'happened': True,
#    'bank': True},
#   '1'),
#  ({'worst': True,
#    'happened': True,
#    'bank': True,
#    'slow': True,
#    'transaction': True,
#    'additional': True,
#    'charge': True,
#    'error': True,
#    'frustrate': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'frustrating': True,
#    'worst': True,
#    'great': True},
#   '1'),
#  ({'bad': True,
#    'advice': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'complicated': True,
#    'figure': True,
#    'online': True,
#    'banking': True},
#   '1'),
#  ({'worst': True, 'great': True}, '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'slow': True,
#    'transaction': True,
#    'bad': True,
#    'advice': True},
#   '1'),
#  ({'great': True,
#    'happened': True,
#    'bank': True,
#    'error': True,
#    'kept': True,
#    'cropping': True},
#   '1'),
#  ({'complicated': True,
#    'figure': True,
#    'lost': True,
#    'detail': True,
#    'staff': True,
#    'unhelpful': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'slow': True,
#    'transaction': True,
#    'frustrate': True,
#    'error': True,
#    'kept': True,
#    'cropping': True,
#    'soo': True,
#    'frustrating': True,
#    'strange': True},
#   '1'),
#  ...]

# %%
import nltk.classify
# Split the data
OS_train_data, OS_test_data = train_test_split(OS_data, test_size=0.25, random_state=42)

# Train the classifier
OS_clf = NaiveBayesClassifier.train(OS_train_data)

print("Classifier accuracy percent:",(nltk.classify.accuracy(OS_clf, OS_test_data))*100)
# Out:
# Classifier accuracy percent: 100.0

# %%
from sklearn.metrics import confusion_matrix

OS_test_actual = [label for _, label in OS_test_data]
OS_test_pred = [OS_clf.classify(features) for features, _ in OS_test_data]

# Generate the confusion matrix using sklearn
OS_cm = confusion_matrix(OS_test_actual, OS_test_pred)


# You might need to explicitly define your labels
OSlabels = sorted(set(OS_test_actual))  # Sort labels if necessary

OS_cm_df = pd.DataFrame(OS_cm, index=OSlabels, columns=OSlabels)

# %%
OS_cm_df
# Out:
#       1     5
# 1  1527     0
# 5     0  1473

# %%
OS_accuracy = accuracy_score(OS_test_actual, OS_test_pred)
print(f"Accuracy: {OS_accuracy:.2f}")



OS_report = classification_report(OS_test_actual, OS_test_pred)
print(OS_report)
# Out:
# Accuracy: 1.00
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1527
#            5       1.00      1.00      1.00      1473
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000

# %%
# Show the most informative features
informative_features =OS_clf.show_most_informative_features(100)
# Out:
# Most Informative Features
#                    fraud = None                1 : 5      =      3.6 : 1.0
#                     rate = True                5 : 1      =      2.1 : 1.0
#                    error = None                5 : 1      =      1.9 : 1.0
#              complicated = None                5 : 1      =      1.8 : 1.0
#              frustrating = None                5 : 1      =      1.8 : 1.0
#                     rate = None                1 : 5      =      1.7 : 1.0
#                    quick = None                1 : 5      =      1.5 : 1.0
#                responded = None                1 : 5      =      1.5 : 1.0
#                   secure = None                1 : 5      =      1.5 : 1.0
#              competitive = None                1 : 5      =      1.5 : 1.0
#                      fee = None                1 : 5      =      1.5 : 1.0
#                    waved = None                1 : 5      =      1.5 : 1.0
#                     case = None                1 : 5      =      1.5 : 1.0
#                   helped = None                1 : 5      =      1.5 : 1.0
#                  helpful = None                1 : 5      =      1.5 : 1.0
#                efficient = None                1 : 5      =      1.5 : 1.0
#                    range = None                1 : 5      =      1.5 : 1.0
#                     wide = None                1 : 5      =      1.5 : 1.0
#                 friendly = None                1 : 5      =      1.5 : 1.0
#                     fast = None                1 : 5      =      1.5 : 1.0
#                  worried = None                1 : 5      =      1.5 : 1.0
#                   stable = None                1 : 5      =      1.5 : 1.0
#                     easy = None                1 : 5      =      1.5 : 1.0
#                      pin = None                1 : 5      =      1.5 : 1.0
#                     poor = None                5 : 1      =      1.4 : 1.0
#                   figure = None                5 : 1      =      1.4 : 1.0
#                 cropping = None                5 : 1      =      1.4 : 1.0
#                     kept = None                5 : 1      =      1.4 : 1.0
#               additional = None                5 : 1      =      1.4 : 1.0
#                   charge = None                5 : 1      =      1.4 : 1.0
#                     rude = None                5 : 1      =      1.4 : 1.0
#                      soo = None                5 : 1      =      1.4 : 1.0
#                  strange = None                5 : 1      =      1.4 : 1.0
#                    great = None                5 : 1      =      1.3 : 1.0
#                    worst = None                5 : 1      =      1.3 : 1.0
#                frustrate = None                5 : 1      =      1.3 : 1.0
#                  limited = None                5 : 1      =      1.3 : 1.0
#                     slow = None                5 : 1      =      1.3 : 1.0
#                     bank = None                5 : 1      =      1.3 : 1.0
#                 happened = None                5 : 1      =      1.3 : 1.0
#                    staff = True                5 : 1      =      1.3 : 1.0
#                   advice = None                5 : 1      =      1.3 : 1.0
#                      bad = None                5 : 1      =      1.3 : 1.0
#                   detail = None                5 : 1      =      1.3 : 1.0
#                unhelpful = None                5 : 1      =      1.3 : 1.0
#                     long = None                5 : 1      =      1.3 : 1.0
#                     time = None                5 : 1      =      1.3 : 1.0
#                     wait = None                5 : 1      =      1.3 : 1.0
#              transaction = True                5 : 1      =      1.3 : 1.0
#                     lost = True                5 : 1      =      1.3 : 1.0
#                 customer = True                5 : 1      =      1.3 : 1.0
#                  banking = True                5 : 1      =      1.3 : 1.0
#                   online = True                5 : 1      =      1.3 : 1.0
#                 interest = True                5 : 1      =      1.2 : 1.0
#                  service = None                1 : 5      =      1.2 : 1.0
#                  service = True                5 : 1      =      1.2 : 1.0
#                    staff = None                1 : 5      =      1.1 : 1.0
#              transaction = None                1 : 5      =      1.1 : 1.0
#                 customer = None                1 : 5      =      1.1 : 1.0
#                     lost = None                1 : 5      =      1.1 : 1.0
#                  banking = None                1 : 5      =      1.1 : 1.0
#                   online = None                1 : 5      =      1.1 : 1.0
#                 interest = None                1 : 5      =      1.1 : 1.0

# %% [markdown]
# ### Mortgages

# %%
# Prepare the data
def document_features(token_list):
    return {token: True for token in token_list}

mort_data = [(document_features(tokens), str(score)) for tokens, score in zip(mort_sample_full1['Tokens'], mort_sample_full1['Rating'])]

# %%
mort_data
# Out:
# [({'insecure': True,
#    'additional': True,
#    'charge': True,
#    'limited': True,
#    'service': True,
#    'hope': True,
#    'youre': True,
#    'proud': True},
#   '1'),
#  ({'happened': True,
#    'fee': True,
#    'rude': True,
#    'customer': True,
#    'service': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'additional': True,
#    'charge': True,
#    'limited': True},
#   '1'),
#  ({'happened': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'distressed': True,
#    'limited': True,
#    'high': True,
#    'fee': True},
#   '1'),
#  ({'high': True,
#    'fee': True,
#    'happened': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'great': True,
#    'mum': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'limited': True,
#    'service': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'unhelpful': True,
#    'staff': True,
#    'mum': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'limited': True,
#    'great': True,
#    'insecure': True},
#   '1'),
#  ({'distressed': True,
#    'mum': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'terrible': True,
#    'manager': True,
#    'insecure': True,
#    'bad': True,
#    'financial': True,
#    'advice': True},
#   '1'),
#  ({'happened': True, 'great': True, 'mum': True}, '1'),
#  ({'hope': True,
#    'youre': True,
#    'proud': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'mum': True,
#    'additional': True,
#    'charge': True,
#    'insecure': True,
#    'great': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'slow': True,
#    'transaction': True,
#    'high': True,
#    'fee': True,
#    'limited': True,
#    'service': True,
#    'unhelpful': True,
#    'staff': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'happened': True,
#    'high': True,
#    'fee': True,
#    'terrible': True,
#    'manager': True},
#   '1'),
#  ({'unhelpful': True,
#    'staff': True,
#    'limited': True,
#    'service': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'happened': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'distressed': True,
#    'high': True,
#    'fee': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'great': True,
#    'happened': True,
#    'unhelpful': True,
#    'staff': True},
#   '1'),
#  ({'mum': True,
#    'rising': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'fee': True},
#   '1'),
#  ({'insecure': True,
#    'great': True,
#    'happened': True,
#    'rude': True,
#    'customer': True,
#    'service': True},
#   '1'),
#  ({'distressed': True, 'additional': True, 'charge': True}, '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'terrible': True,
#    'manager': True,
#    'limited': True,
#    'service': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'insecure': True,
#    'distressed': True},
#   '1'),
#  ({'rising': True,
#    'happened': True,
#    'slow': True,
#    'transaction': True,
#    'high': True,
#    'fee': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'hope': True,
#    'youre': True,
#    'proud': True,
#    'additional': True,
#    'charge': True,
#    'mum': True,
#    'slow': True,
#    'transaction': True,
#    'terrible': True,
#    'manager': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'great': True,
#    'high': True,
#    'fee': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'terrible': True,
#    'manager': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'unhelpful': True,
#    'staff': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'rising': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'terrible': True,
#    'manager': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'high': True,
#    'fee': True,
#    'limited': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'rising': True,
#    'happened': True,
#    'fee': True},
#   '1'),
#  ({'happened': True,
#    'mum': True,
#    'insecure': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'terrible': True,
#    'manager': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'mum': True,
#    'additional': True,
#    'charge': True,
#    'limited': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'insecure': True,
#    'limited': True,
#    'service': True,
#    'additional': True,
#    'charge': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'terrible': True,
#    'manager': True},
#   '1'),
#  ({'fee': True,
#    'rising': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'rude': True,
#    'customer': True,
#    'service': True},
#   '1'),
#  ({'rising': True,
#    'great': True,
#    'fee': True,
#    'mum': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'slow': True,
#    'transaction': True,
#    'terrible': True,
#    'manager': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'insecure': True,
#    'great': True,
#    'happened': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'unhelpful': True,
#    'staff': True},
#   '1'),
#  ({'fee': True,
#    'happened': True,
#    'mum': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'happened': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'rising': True},
#   '1'),
#  ({'fee': True, 'rising': True, 'unhelpful': True, 'staff': True}, '1'),
#  ({'great': True, 'insecure': True, 'slow': True, 'transaction': True}, '1'),
#  ({'mum': True,
#    'high': True,
#    'fee': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'rising': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'high': True,
#    'fee': True,
#    'terrible': True,
#    'manager': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'mum': True,
#    'unhelpful': True,
#    'staff': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'rising': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'limited': True},
#   '1'),
#  ({'high': True,
#    'fee': True,
#    'limited': True,
#    'service': True,
#    'rude': True,
#    'customer': True,
#    'rising': True,
#    'mum': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'great': True,
#    'mum': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'rising': True,
#    'high': True,
#    'fee': True,
#    'mum': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'mum': True,
#    'great': True,
#    'unhelpful': True,
#    'staff': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'fee': True,
#    'rising': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'unhelpful': True,
#    'staff': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'high': True,
#    'fee': True,
#    'slow': True,
#    'transaction': True,
#    'mum': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'limited': True,
#    'service': True,
#    'additional': True,
#    'charge': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'bad': True,
#    'financial': True,
#    'advice': True},
#   '1'),
#  ({'terrible': True,
#    'manager': True,
#    'mum': True,
#    'great': True,
#    'unhelpful': True,
#    'staff': True,
#    'fee': True},
#   '1'),
#  ({'happened': True,
#    'terrible': True,
#    'manager': True,
#    'fee': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'slow': True,
#    'transaction': True,
#    'terrible': True,
#    'manager': True,
#    'insecure': True,
#    'fee': True,
#    'great': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'insecure': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'fee': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'rising': True,
#    'slow': True,
#    'transaction': True,
#    'high': True,
#    'fee': True,
#    'limited': True,
#    'service': True,
#    'rude': True,
#    'customer': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'happened': True},
#   '1'),
#  ({'unhelpful': True,
#    'staff': True,
#    'slow': True,
#    'transaction': True,
#    'fee': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'mum': True,
#    'high': True},
#   '1'),
#  ({'hope': True,
#    'youre': True,
#    'proud': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'mum': True,
#    'rising': True,
#    'high': True,
#    'fee': True,
#    'rude': True,
#    'customer': True,
#    'service': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'great': True,
#    'mum': True,
#    'happened': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'mum': True,
#    'high': True,
#    'fee': True,
#    'great': True,
#    'insecure': True,
#    'unhelpful': True,
#    'staff': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'distressed': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'happened': True,
#    'terrible': True,
#    'manager': True,
#    'insecure': True},
#   '1'),
#  ({'fee': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'rising': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'terrible': True,
#    'manager': True,
#    'great': True,
#    'high': True,
#    'fee': True,
#    'insecure': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'distressed': True,
#    'insecure': True,
#    'rising': True,
#    'high': True,
#    'fee': True,
#    'great': True},
#   '1'),
#  ({'insecure': True,
#    'high': True,
#    'fee': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'rising': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'terrible': True,
#    'manager': True,
#    'insecure': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'happened': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'rising': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'happened': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'slow': True,
#    'transaction': True,
#    'great': True,
#    'happened': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'distressed': True,
#    'slow': True,
#    'transaction': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'high': True,
#    'fee': True},
#   '1'),
#  ({'terrible': True,
#    'manager': True,
#    'distressed': True,
#    'insecure': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'rising': True},
#   '1'),
#  ({'high': True,
#    'fee': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'distressed': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'limited': True,
#    'service': True,
#    'additional': True,
#    'charge': True,
#    'rude': True,
#    'customer': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'rising': True,
#    'distressed': True,
#    'happened': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'hope': True,
#    'youre': True,
#    'proud': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'unhelpful': True,
#    'staff': True},
#   '1'),
#  ({'mum': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'distressed': True,
#    'great': True,
#    'happened': True},
#   '1'),
#  ({'fee': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'happened': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'great': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'great': True,
#    'hope': True,
#    'youre': True,
#    'proud': True},
#   '1'),
#  ({'rising': True,
#    'high': True,
#    'fee': True,
#    'terrible': True,
#    'manager': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'slow': True,
#    'transaction': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'terrible': True, 'manager': True, 'insecure': True, 'rising': True}, '1'),
#  ({'mum': True, 'high': True, 'fee': True, 'distressed': True}, '1'),
#  ({'insecure': True,
#    'distressed': True,
#    'terrible': True,
#    'manager': True,
#    'additional': True,
#    'charge': True,
#    'rising': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'unhelpful': True,
#    'staff': True,
#    'rude': True,
#    'customer': True,
#    'service': True},
#   '1'),
#  ({'unhelpful': True,
#    'staff': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'happened': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'great': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'hope': True,
#    'youre': True,
#    'proud': True,
#    'great': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'rising': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'unhelpful': True,
#    'staff': True,
#    'limited': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'fee': True,
#    'happened': True,
#    'terrible': True,
#    'manager': True,
#    'slow': True,
#    'transaction': True,
#    'rising': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'terrible': True,
#    'manager': True},
#   '1'),
#  ({'great': True,
#    'terrible': True,
#    'manager': True,
#    'unhelpful': True,
#    'staff': True,
#    'limited': True,
#    'service': True,
#    'rising': True,
#    'happened': True},
#   '1'),
#  ({'terrible': True,
#    'manager': True,
#    'distressed': True,
#    'insecure': True,
#    'happened': True},
#   '1'),
#  ({'insecure': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'distressed': True,
#    'happened': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'fee': True,
#    'great': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'bad': True,
#    'financial': True,
#    'advice': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'slow': True,
#    'transaction': True,
#    'happened': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'distressed': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'unhelpful': True, 'staff': True, 'mum': True, 'insecure': True}, '1'),
#  ({'mum': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'insecure': True,
#    'terrible': True,
#    'manager': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'insecure': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'happened': True,
#    'fee': True,
#    'rising': True},
#   '1'),
#  ({'fee': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'terrible': True,
#    'manager': True,
#    'slow': True,
#    'transaction': True,
#    'great': True,
#    'distressed': True,
#    'fee': True,
#    'hope': True,
#    'youre': True,
#    'proud': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'insecure': True,
#    'limited': True,
#    'service': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'rising': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'insecure': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'insecure': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'happened': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'rising': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'distressed': True,
#    'great': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'rising': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'great': True,
#    'high': True,
#    'fee': True,
#    'mum': True,
#    'rude': True,
#    'customer': True,
#    'service': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'limited': True,
#    'service': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'distressed': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'happened': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'mum': True,
#    'hope': True,
#    'youre': True,
#    'proud': True},
#   '1'),
#  ({'distressed': True,
#    'great': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'slow': True,
#    'transaction': True,
#    'mum': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'fee': True,
#    'high': True},
#   '1'),
#  ({'happened': True,
#    'mum': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'limited': True,
#    'service': True,
#    'rising': True},
#   '1'),
#  ({'rising': True,
#    'unhelpful': True,
#    'staff': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'fee': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'rising': True,
#    'limited': True,
#    'service': True,
#    'mum': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'distressed': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'mum': True},
#   '1'),
#  ({'high': True,
#    'fee': True,
#    'insecure': True,
#    'unhelpful': True,
#    'staff': True,
#    'terrible': True,
#    'manager': True},
#   '1'),
#  ({'distressed': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'happened': True,
#    'great': True,
#    'insecure': True,
#    'mum': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'unhelpful': True,
#    'staff': True,
#    'slow': True,
#    'transaction': True,
#    'bad': True,
#    'financial': True,
#    'advice': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'distressed': True,
#    'great': True,
#    'happened': True},
#   '1'),
#  ({'great': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'unhelpful': True,
#    'staff': True},
#   '1'),
#  ({'happened': True,
#    'terrible': True,
#    'manager': True,
#    'unhelpful': True,
#    'staff': True,
#    'insecure': True,
#    'mum': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'distressed': True,
#    'insecure': True,
#    'limited': True,
#    'service': True,
#    'hope': True,
#    'youre': True,
#    'proud': True},
#   '1'),
#  ({'distressed': True,
#    'great': True,
#    'insecure': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'unhelpful': True,
#    'staff': True,
#    'mum': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'mum': True,
#    'rising': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'bad': True,
#    'financial': True,
#    'advice': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'high': True,
#    'fee': True,
#    'rising': True,
#    'insecure': True},
#   '1'),
#  ({'terrible': True,
#    'manager': True,
#    'mum': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'fee': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'mum': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'happened': True},
#   '1'),
#  ({'unhelpful': True,
#    'staff': True,
#    'slow': True,
#    'transaction': True,
#    'happened': True,
#    'additional': True,
#    'charge': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'insecure': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'insecure': True,
#    'high': True,
#    'fee': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'limited': True, 'service': True, 'rising': True, 'mum': True}, '1'),
#  ({'unhelpful': True,
#    'staff': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'high': True,
#    'fee': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'great': True,
#    'unhelpful': True,
#    'staff': True,
#    'limited': True,
#    'service': True,
#    'rising': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'unhelpful': True,
#    'staff': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'terrible': True,
#    'manager': True},
#   '1'),
#  ({'great': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'fee': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'hope': True,
#    'youre': True,
#    'proud': True,
#    'slow': True,
#    'transaction': True,
#    'high': True,
#    'fee': True,
#    'rising': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'mum': True,
#    'rising': True,
#    'additional': True,
#    'charge': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'fee': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'distressed': True,
#    'slow': True,
#    'transaction': True,
#    'high': True,
#    'fee': True,
#    'insecure': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'happened': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'terrible': True,
#    'manager': True,
#    'great': True,
#    'mum': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'high': True,
#    'fee': True},
#   '1'),
#  ({'hope': True,
#    'youre': True,
#    'proud': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'happened': True,
#    'insecure': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'happened': True},
#   '1'),
#  ({'great': True,
#    'high': True,
#    'fee': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'happened': True,
#    'insecure': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'unhelpful': True,
#    'staff': True,
#    'fee': True,
#    'insecure': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'mum': True,
#    'limited': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'high': True,
#    'fee': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'distressed': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'high': True,
#    'fee': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'limited': True,
#    'service': True,
#    'slow': True,
#    'transaction': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'distressed': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'rising': True,
#    'additional': True,
#    'charge': True,
#    'fee': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'distressed': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'limited': True,
#    'service': True,
#    'happened': True,
#    'fee': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'high': True,
#    'fee': True},
#   '1'),
#  ({'mum': True,
#    'terrible': True,
#    'manager': True,
#    'additional': True,
#    'charge': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'insecure': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'distressed': True,
#    'slow': True,
#    'transaction': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'great': True,
#    'hope': True,
#    'youre': True,
#    'proud': True},
#   '1'),
#  ({'terrible': True,
#    'manager': True,
#    'insecure': True,
#    'limited': True,
#    'service': True,
#    'great': True,
#    'rising': True,
#    'unhelpful': True,
#    'staff': True},
#   '1'),
#  ({'distressed': True,
#    'happened': True,
#    'limited': True,
#    'service': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'great': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'rising': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'great': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'mum': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'happened': True,
#    'high': True,
#    'fee': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'slow': True,
#    'transaction': True,
#    'additional': True,
#    'charge': True,
#    'terrible': True,
#    'manager': True},
#   '1'),
#  ({'unhelpful': True,
#    'staff': True,
#    'rising': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'high': True,
#    'fee': True,
#    'terrible': True,
#    'manager': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'additional': True,
#    'charge': True,
#    'happened': True,
#    'fee': True,
#    'terrible': True,
#    'manager': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'high': True, 'fee': True, 'rising': True, 'happened': True}, '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'mum': True,
#    'limited': True,
#    'service': True,
#    'happened': True,
#    'rising': True,
#    'hope': True,
#    'youre': True,
#    'proud': True},
#   '1'),
#  ({'insecure': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'happened': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'additional': True,
#    'charge': True,
#    'great': True},
#   '1'),
#  ({'terrible': True, 'manager': True, 'unhelpful': True, 'staff': True}, '1'),
#  ({'terrible': True,
#    'manager': True,
#    'unhelpful': True,
#    'staff': True,
#    'high': True,
#    'fee': True,
#    'distressed': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'rising': True, 'distressed': True, 'happened': True, 'mum': True}, '1'),
#  ({'rising': True, 'hope': True, 'youre': True, 'proud': True}, '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'great': True,
#    'distressed': True,
#    'happened': True,
#    'insecure': True,
#    'terrible': True,
#    'manager': True,
#    'high': True,
#    'fee': True},
#   '1'),
#  ({'mum': True,
#    'insecure': True,
#    'slow': True,
#    'transaction': True,
#    'additional': True,
#    'charge': True,
#    'great': True},
#   '1'),
#  ({'high': True,
#    'fee': True,
#    'insecure': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'unhelpful': True,
#    'staff': True,
#    'terrible': True,
#    'manager': True,
#    'rising': True,
#    'great': True,
#    'distressed': True,
#    'happened': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'fee': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'hope': True,
#    'youre': True,
#    'proud': True,
#    'terrible': True,
#    'manager': True,
#    'happened': True},
#   '1'),
#  ({'terrible': True,
#    'manager': True,
#    'distressed': True,
#    'additional': True,
#    'charge': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'rising': True,
#    'high': True,
#    'fee': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'great': True,
#    'limited': True,
#    'distressed': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'bad': True,
#    'financial': True,
#    'advice': True},
#   '1'),
#  ({'great': True,
#    'additional': True,
#    'charge': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'mum': True,
#    'hope': True,
#    'youre': True,
#    'proud': True},
#   '1'),
#  ({'great': True, 'terrible': True, 'manager': True, 'rising': True}, '1'),
#  ({'hope': True,
#    'youre': True,
#    'proud': True,
#    'unhelpful': True,
#    'staff': True,
#    'terrible': True,
#    'manager': True},
#   '1'),
#  ({'high': True,
#    'fee': True,
#    'rising': True,
#    'unhelpful': True,
#    'staff': True},
#   '1'),
#  ({'hope': True,
#    'youre': True,
#    'proud': True,
#    'happened': True,
#    'mum': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'fee': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'terrible': True,
#    'manager': True,
#    'insecure': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'mum': True,
#    'unhelpful': True,
#    'staff': True,
#    'rude': True,
#    'customer': True,
#    'service': True},
#   '1'),
#  ({'fee': True,
#    'high': True,
#    'distressed': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'limited': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'terrible': True, 'manager': True, 'additional': True, 'charge': True},
#   '1'),
#  ({'happened': True,
#    'slow': True,
#    'transaction': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'happened': True,
#    'insecure': True,
#    'unhelpful': True,
#    'staff': True,
#    'distressed': True,
#    'fee': True},
#   '1'),
#  ({'terrible': True,
#    'manager': True,
#    'mum': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'unhelpful': True,
#    'staff': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'fee': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'unhelpful': True,
#    'staff': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'happened': True,
#    'hope': True,
#    'youre': True,
#    'proud': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'insecure': True,
#    'high': True,
#    'fee': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'hope': True,
#    'youre': True,
#    'proud': True,
#    'fee': True,
#    'mum': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'rude': True,
#    'customer': True,
#    'service': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'limited': True,
#    'service': True,
#    'happened': True,
#    'high': True,
#    'fee': True,
#    'rude': True,
#    'customer': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'rising': True,
#    'distressed': True,
#    'mum': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'insecure': True},
#   '1'),
#  ({'unhelpful': True,
#    'staff': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'additional': True,
#    'charge': True,
#    'slow': True,
#    'transaction': True,
#    'rising': True},
#   '1'),
#  ({'mum': True,
#    'fee': True,
#    'happened': True,
#    'additional': True,
#    'charge': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'mum': True,
#    'rude': True,
#    'customer': True,
#    'bad': True,
#    'financial': True,
#    'advice': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'fee': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'unhelpful': True,
#    'staff': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'fee': True,
#    'bad': True,
#    'financial': True,
#    'advice': True},
#   '1'),
#  ({'hope': True,
#    'youre': True,
#    'proud': True,
#    'mum': True,
#    'limited': True,
#    'service': True,
#    'fee': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'rising': True,
#    'insecure': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'mum': True,
#    'slow': True,
#    'transaction': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'distressed': True,
#    'limited': True,
#    'service': True,
#    'terrible': True,
#    'manager': True,
#    'fee': True},
#   '1'),
#  ({'terrible': True,
#    'manager': True,
#    'rising': True,
#    'unhelpful': True,
#    'staff': True,
#    'fee': True,
#    'mum': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'rude': True,
#    'customer': True,
#    'service': True,
#    'high': True,
#    'fee': True,
#    'insecure': True,
#    'slow': True,
#    'transaction': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'great': True,
#    'unhelpful': True,
#    'staff': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'distressed': True,
#    'insecure': True,
#    'great': True,
#    'mum': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'happened': True,
#    'terrible': True,
#    'manager': True,
#    'fee': True,
#    'unhelpful': True,
#    'staff': True},
#   '1'),
#  ({'fee': True,
#    'happened': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'great': True,
#    'hope': True,
#    'youre': True,
#    'proud': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'rude': True,
#    'customer': True,
#    'terrible': True,
#    'manager': True,
#    'great': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'rising': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'additional': True,
#    'charge': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'mum': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'happened': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'high': True,
#    'fee': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'mum': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'slow': True,
#    'transaction': True,
#    'rising': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'terrible': True,
#    'manager': True,
#    'insecure': True,
#    'slow': True,
#    'transaction': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'high': True,
#    'fee': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'slow': True,
#    'transaction': True,
#    'high': True,
#    'fee': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'great': True,
#    'rising': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'limited': True,
#    'service': True,
#    'insecure': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'unhelpful': True,
#    'staff': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'limited': True,
#    'service': True,
#    'mum': True},
#   '1'),
#  ({'terrible': True,
#    'manager': True,
#    'mum': True,
#    'slow': True,
#    'transaction': True,
#    'limited': True,
#    'service': True,
#    'hope': True,
#    'youre': True,
#    'proud': True},
#   '1'),
#  ({'insecure': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'terrible': True, 'manager': True, 'rising': True, 'mum': True}, '1'),
#  ({'fee': True,
#    'distressed': True,
#    'limited': True,
#    'service': True,
#    'high': True,
#    'happened': True},
#   '1'),
#  ({'insecure': True,
#    'additional': True,
#    'charge': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'slow': True,
#    'transaction': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'happened': True},
#   '1'),
#  ({'terrible': True,
#    'manager': True,
#    'distressed': True,
#    'unhelpful': True,
#    'staff': True,
#    'slow': True,
#    'transaction': True,
#    'mum': True,
#    'rising': True},
#   '1'),
#  ({'hope': True,
#    'youre': True,
#    'proud': True,
#    'happened': True,
#    'high': True,
#    'fee': True},
#   '1'),
#  ({'insecure': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'unhelpful': True,
#    'staff': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'happened': True,
#    'great': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'additional': True,
#    'charge': True,
#    'unhelpful': True,
#    'staff': True},
#   '1'),
#  ({'hope': True,
#    'youre': True,
#    'proud': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'great': True,
#    'high': True,
#    'fee': True},
#   '1'),
#  ({'long': True,
#    'wait': True,
#    'time': True,
#    'slow': True,
#    'transaction': True,
#    'fee': True,
#    'terrible': True,
#    'manager': True,
#    'distressed': True,
#    'insecure': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'limited': True,
#    'service': True,
#    'insecure': True,
#    'rising': True},
#   '1'),
#  ({'insecure': True,
#    'rising': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'fee': True,
#    'terrible': True,
#    'manager': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'high': True,
#    'fee': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'limited': True,
#    'service': True,
#    'rude': True,
#    'customer': True},
#   '1'),
#  ({'fee': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'distressed': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'fee': True,
#    'additional': True,
#    'charge': True,
#    'great': True,
#    'happened': True},
#   '1'),
#  ({'distressed': True,
#    'slow': True,
#    'transaction': True,
#    'happened': True,
#    'high': True,
#    'fee': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'terrible': True,
#    'manager': True,
#    'unhelpful': True,
#    'staff': True,
#    'rising': True,
#    'fee': True},
#   '1'),
#  ({'high': True, 'fee': True, 'terrible': True, 'manager': True}, '1'),
#  ({'additional': True,
#    'charge': True,
#    'great': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'slow': True,
#    'transaction': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'limited': True,
#    'insecure': True},
#   '1'),
#  ({'happened': True, 'mum': True, 'hope': True, 'youre': True, 'proud': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'unhelpful': True,
#    'staff': True,
#    'terrible': True,
#    'manager': True,
#    'slow': True,
#    'transaction': True,
#    'distressed': True},
#   '1'),
#  ({'mum': True,
#    'insecure': True,
#    'terrible': True,
#    'manager': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'rising': True,
#    'distressed': True,
#    'unhelpful': True,
#    'staff': True,
#    'mum': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'great': True,
#    'additional': True,
#    'charge': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'terrible': True,
#    'manager': True,
#    'fee': True},
#   '1'),
#  ({'distressed': True,
#    'happened': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'great': True},
#   '1'),
#  ({'slow': True,
#    'transaction': True,
#    'limited': True,
#    'service': True,
#    'great': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'slow': True,
#    'transaction': True,
#    'terrible': True,
#    'manager': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'additional': True,
#    'charge': True,
#    'unhelpful': True,
#    'staff': True},
#   '1'),
#  ({'high': True,
#    'fee': True,
#    'distressed': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'mum': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'terrible': True,
#    'manager': True,
#    'slow': True,
#    'transaction': True,
#    'high': True,
#    'fee': True},
#   '1'),
#  ({'distressed': True,
#    'high': True,
#    'fee': True,
#    'mum': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'distressed': True,
#    'fee': True,
#    'happened': True,
#    'terrible': True,
#    'manager': True,
#    'great': True,
#    'rude': True,
#    'customer': True,
#    'service': True},
#   '1'),
#  ({'distressed': True,
#    'happened': True,
#    'additional': True,
#    'charge': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'happened': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'high': True,
#    'fee': True,
#    'distressed': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'unhelpful': True,
#    'staff': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'slow': True,
#    'transaction': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'rude': True,
#    'customer': True,
#    'service': True},
#   '1'),
#  ({'mum': True,
#    'high': True,
#    'fee': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'bad': True,
#    'financial': True,
#    'advice': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'insecure': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'high': True,
#    'fee': True,
#    'great': True,
#    'rising': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'happened': True,
#    'additional': True,
#    'charge': True,
#    'fee': True,
#    'terrible': True,
#    'manager': True},
#   '1'),
#  ({'unhelpful': True,
#    'staff': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'limited': True,
#    'service': True,
#    'insecure': True,
#    'rising': True},
#   '1'),
#  ({'hope': True,
#    'youre': True,
#    'proud': True,
#    'additional': True,
#    'charge': True,
#    'fee': True,
#    'unhelpful': True,
#    'staff': True},
#   '1'),
#  ({'rising': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'great': True,
#    'terrible': True,
#    'manager': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'fee': True,
#    'terrible': True,
#    'manager': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'bad': True,
#    'financial': True,
#    'advice': True},
#   '1'),
#  ({'happened': True,
#    'insecure': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'slow': True,
#    'transaction': True,
#    'hope': True,
#    'youre': True,
#    'proud': True},
#   '1'),
#  ({'limited': True,
#    'service': True,
#    'great': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'happened': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'poor': True,
#    'interest': True,
#    'rate': True},
#   '1'),
#  ({'distressed': True, 'rising': True, 'high': True, 'fee': True}, '1'),
#  ({'terrible': True,
#    'manager': True,
#    'unhelpful': True,
#    'staff': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'limited': True,
#    'service': True,
#    'mum': True,
#    'rude': True,
#    'customer': True,
#    'high': True,
#    'fee': True},
#   '1'),
#  ({'unhelpful': True,
#    'staff': True,
#    'mum': True,
#    'happened': True,
#    'great': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'distressed': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'rising': True,
#    'happened': True,
#    'terrible': True,
#    'manager': True,
#    'limited': True,
#    'service': True,
#    'additional': True,
#    'charge': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'slow': True,
#    'transaction': True,
#    'insecure': True,
#    'great': True,
#    'fee': True},
#   '1'),
#  ({'additional': True,
#    'charge': True,
#    'insecure': True,
#    'poor': True,
#    'interest': True,
#    'rate': True,
#    'high': True,
#    'fee': True,
#    'limited': True,
#    'service': True},
#   '1'),
#  ({'distressed': True,
#    'high': True,
#    'fee': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'unhelpful': True,
#    'staff': True,
#    'rising': True,
#    'fee': True,
#    'insecure': True},
#   '1'),
#  ({'distressed': True,
#    'high': True,
#    'fee': True,
#    'insecure': True,
#    'great': True,
#    'unhelpful': True,
#    'staff': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'distressed': True,
#    'unhelpful': True,
#    'staff': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'insecure': True,
#    'great': True},
#   '1'),
#  ({'terrible': True,
#    'manager': True,
#    'distressed': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'rising': True,
#    'unhelpful': True,
#    'staff': True},
#   '1'),
#  ({'high': True,
#    'fee': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'distressed': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'great': True,
#    'fee': True,
#    'limited': True,
#    'service': True,
#    'bad': True,
#    'financial': True,
#    'advice': True,
#    'long': True,
#    'wait': True,
#    'time': True},
#   '1'),
#  ({'terrible': True,
#    'manager': True,
#    'mum': True,
#    'rude': True,
#    'customer': True,
#    'service': True,
#    'slow': True,
#    'transaction': True},
#   '1'),
#  ({'poor': True,
#    'interest': True,
#    'rate': True,
#    'hope': True,
#    'youre': True,
#    'proud': True,
#    'great': True,
#    'long': True,
#    'wait': True,
#    'time': True,
#    'limited': True,
#    'service': True,
#    'rising': True,
#    'fee': True},
#   '1'),
#  ({'insecure': True,
# ...
#   '5'),
#  ({'helpful': True,
#    'customer': True,
#    'service': True,
#    'reliable': True,
#    'ease': True,
#    'stressed': True,
#    'first': True,
#    'tho': True,
#    'friendly': True,
#    'staff': True},
#   '5'),
#  ({'froze': True,
#    'interest': True,
#    'rate': True,
#    'stressed': True,
#    'first': True,
#    'tho': True,
#    'good': True,
#    'bad': True},
#   '5'),
#  ({'easy': True,
#    'online': True,
#    'banking': True,
#    'good': True,
#    'competitive': True,
#    'rate': True,
#    'helpful': True,
#    'customer': True,
#    'service': True,
#    'fast': True,
#    'transaction': True},
#   '5'),
#  ({'bad': True,
#    'helpful': True,
#    'customer': True,
#    'service': True,
#    'friendly': True,
#    'staff': True},
#   '5'),
#  ({'good': True,
#    'excellent': True,
#    'financial': True,
#    'advice': True,
#    'competitive': True,
#    'rate': True,
#    'easy': True,
#    'online': True,
#    'banking': True,
#    'friendly': True,
#    'staff': True},
#   '5'),
#  ({'stressed': True,
#    'first': True,
#    'tho': True,
#    'worried': True,
#    'got': True,
#    'really': True,
#    'helpful': True,
#    'advise': True,
#    'remorgaging': True,
#    'competitive': True,
#    'rate': True,
#    'bad': True},
#   '5'),
#  ({'fast': True,
#    'transaction': True,
#    'helpful': True,
#    'customer': True,
#    'service': True,
#    'worried': True,
#    'got': True,
#    'really': True,
#    'advise': True,
#    'remorgaging': True},
#   '5'),
#  ({'ease': True,
#    'thank': True,
#    'friendly': True,
#    'staff': True,
#    'bad': True,
#    'worried': True,
#    'got': True,
#    'really': True,
#    'helpful': True,
#    'advise': True,
#    'remorgaging': True},
#   '5'),
#  ({'reliable': True,
#    'ease': True,
#    'excellent': True,
#    'financial': True,
#    'advice': True},
#   '5'),
#  ({'froze': True,
#    'interest': True,
#    'rate': True,
#    'ease': True,
#    'worried': True,
#    'got': True,
#    'really': True,
#    'helpful': True,
#    'advise': True,
#    'remorgaging': True},
#   '5'),
#  ({'waved': True,
#    'fee': True,
#    'thank': True,
#    'wide': True,
#    'range': True,
#    'service': True,
#    'remortgaged': True},
#   '5'),
#  ({'worried': True,
#    'got': True,
#    'really': True,
#    'helpful': True,
#    'advise': True,
#    'remorgaging': True,
#    'easy': True,
#    'online': True,
#    'banking': True,
#    'remortgaged': True,
#    'stressed': True,
#    'first': True,
#    'tho': True,
#    'customer': True,
#    'service': True},
#   '5'),
#  ({'stressed': True,
#    'first': True,
#    'tho': True,
#    'good': True,
#    'waved': True,
#    'fee': True,
#    'fast': True,
#    'transaction': True,
#    'helpful': True,
#    'customer': True,
#    'service': True},
#   '5'),
#  ({'fast': True,
#    'transaction': True,
#    'reliable': True,
#    'froze': True,
#    'interest': True,
#    'rate': True,
#    'good': True,
#    'thank': True,
#    'remortgaged': True},
#   '5'),
#  ({'excellent': True,
#    'financial': True,
#    'advice': True,
#    'easy': True,
#    'online': True,
#    'banking': True,
#    'ease': True,
#    'thank': True},
#   '5'),
#  ({'thank': True,
#    'froze': True,
#    'interest': True,
#    'rate': True,
#    'reliable': True,
#    'fast': True,
#    'transaction': True,
#    'waved': True,
#    'fee': True},
#   '5'),
#  ({'excellent': True,
#    'financial': True,
#    'advice': True,
#    'helpful': True,
#    'customer': True,
#    'service': True,
#    'wide': True,
#    'range': True,
#    'bad': True},
#   '5'),
#  ({'helpful': True,
#    'customer': True,
#    'service': True,
#    'easy': True,
#    'online': True,
#    'banking': True,
#    'wide': True,
#    'range': True,
#    'thank': True,
#    'reliable': True},
#   '5'),
#  ({'helpful': True,
#    'customer': True,
#    'service': True,
#    'reliable': True,
#    'stressed': True,
#    'first': True,
#    'tho': True,
#    'bad': True,
#    'ease': True},
#   '5'),
#  ({'friendly': True,
#    'staff': True,
#    'thank': True,
#    'waved': True,
#    'fee': True,
#    'froze': True,
#    'interest': True,
#    'rate': True,
#    'ease': True},
#   '5'),
#  ({'bad': True,
#    'worried': True,
#    'got': True,
#    'really': True,
#    'helpful': True,
#    'advise': True,
#    'remorgaging': True,
#    'easy': True,
#    'online': True,
#    'banking': True,
#    'friendly': True,
#    'staff': True},
#   '5'),
#  ({'worried': True,
#    'got': True,
#    'really': True,
#    'helpful': True,
#    'advise': True,
#    'remorgaging': True,
#    'froze': True,
#    'interest': True,
#    'rate': True,
#    'excellent': True,
#    'financial': True,
#    'advice': True,
#    'wide': True,
#    'range': True,
#    'service': True,
#    'good': True,
#    'remortgaged': True},
#   '5'),
#  ({'friendly': True,
#    'staff': True,
#    'competitive': True,
#    'rate': True,
#    'remortgaged': True,
#    'fast': True,
#    'transaction': True},
#   '5'),
#  ({'bad': True,
#    'froze': True,
#    'interest': True,
#    'rate': True,
#    'helpful': True,
#    'customer': True,
#    'service': True,
#    'good': True,
#    'competitive': True,
#    'easy': True,
#    'online': True,
#    'banking': True,
#    'thank': True,
#    'reliable': True},
#   '5'),
#  ({'wide': True,
#    'range': True,
#    'service': True,
#    'stressed': True,
#    'first': True,
#    'tho': True,
#    'bad': True},
#   '5'),
#  ({'waved': True,
#    'fee': True,
#    'competitive': True,
#    'rate': True,
#    'ease': True,
#    'friendly': True,
#    'staff': True,
#    'bad': True},
#   '5'),
#  ({'thank': True,
#    'wide': True,
#    'range': True,
#    'service': True,
#    'excellent': True,
#    'financial': True,
#    'advice': True,
#    'good': True,
#    'helpful': True,
#    'customer': True,
#    'froze': True,
#    'interest': True,
#    'rate': True,
#    'friendly': True,
#    'staff': True},
#   '5'),
#  ({'froze': True,
#    'interest': True,
#    'rate': True,
#    'bad': True,
#    'good': True,
#    'competitive': True,
#    'helpful': True,
#    'customer': True,
#    'service': True},
#   '5'),
#  ({'fast': True,
#    'transaction': True,
#    'thank': True,
#    'reliable': True,
#    'ease': True,
#    'competitive': True,
#    'rate': True,
#    'easy': True,
#    'online': True,
#    'banking': True},
#   '5'),
#  ({'froze': True,
#    'interest': True,
#    'rate': True,
#    'easy': True,
#    'online': True,
#    'banking': True,
#    'stressed': True,
#    'first': True,
#    'tho': True,
#    'fast': True,
#    'transaction': True,
#    'waved': True,
#    'fee': True,
#    'helpful': True,
#    'customer': True,
#    'service': True},
#   '5'),
#  ({'good': True,
#    'remortgaged': True,
#    'froze': True,
#    'interest': True,
#    'rate': True,
#    'waved': True,
#    'fee': True},
#   '5'),
#  ({'easy': True,
#    'online': True,
#    'banking': True,
#    'excellent': True,
#    'financial': True,
#    'advice': True,
#    'thank': True,
#    'wide': True,
#    'range': True,
#    'service': True,
#    'bad': True,
#    'stressed': True,
#    'first': True,
#    'tho': True},
#   '5'),
#  ({'froze': True,
#    'interest': True,
#    'rate': True,
#    'good': True,
#    'excellent': True,
#    'financial': True,
#    'advice': True,
#    'bad': True},
#   '5'),
#  ({'easy': True,
#    'online': True,
#    'banking': True,
#    'friendly': True,
#    'staff': True,
#    'remortgaged': True,
#    'fast': True,
#    'transaction': True,
#    'competitive': True,
#    'rate': True},
#   '5'),
#  ({'friendly': True,
#    'staff': True,
#    'competitive': True,
#    'rate': True,
#    'remortgaged': True},
#   '5'),
#  ({'ease': True,
#    'helpful': True,
#    'customer': True,
#    'service': True,
#    'remortgaged': True,
#    'wide': True,
#    'range': True,
#    'fast': True,
#    'transaction': True,
#    'competitive': True,
#    'rate': True},
#   '5'),
#  ({'waved': True,
#    'fee': True,
#    'ease': True,
#    'froze': True,
#    'interest': True,
#    'rate': True,
#    'stressed': True,
#    'first': True,
#    'tho': True,
#    'competitive': True},
#   '5'),
#  ({'excellent': True,
#    'financial': True,
#    'advice': True,
#    'helpful': True,
#    'customer': True,
#    'service': True,
#    'friendly': True,
#    'staff': True,
#    'competitive': True,
#    'rate': True,
#    'bad': True},
#   '5'),
#  ({'wide': True,
#    'range': True,
#    'service': True,
#    'reliable': True,
#    'friendly': True,
#    'staff': True,
#    'good': True,
#    'froze': True,
#    'interest': True,
#    'rate': True,
#    'fast': True,
#    'transaction': True,
#    'thank': True},
#   '5'),
#  ({'wide': True,
#    'range': True,
#    'service': True,
#    'remortgaged': True,
#    'good': True,
#    'thank': True},
#   '5'),
#  ({'helpful': True,
#    'customer': True,
#    'service': True,
#    'thank': True,
#    'bad': True,
#    'ease': True,
#    'good': True,
#    'reliable': True},
#   '5'),
#  ({'stressed': True,
#    'first': True,
#    'tho': True,
#    'reliable': True,
#    'competitive': True,
#    'rate': True,
#    'waved': True,
#    'fee': True},
#   '5'),
#  ({'waved': True,
#    'fee': True,
#    'friendly': True,
#    'staff': True,
#    'reliable': True,
#    'thank': True,
#    'worried': True,
#    'got': True,
#    'really': True,
#    'helpful': True,
#    'advise': True,
#    'remorgaging': True},
#   '5'),
#  ({'reliable': True, 'good': True}, '5'),
#  ({'easy': True,
#    'online': True,
#    'banking': True,
#    'wide': True,
#    'range': True,
#    'service': True,
#    'thank': True,
#    'fast': True,
#    'transaction': True,
#    'excellent': True,
#    'financial': True,
#    'advice': True,
#    'remortgaged': True},
#   '5'),
#  ({'waved': True,
#    'fee': True,
#    'excellent': True,
#    'financial': True,
#    'advice': True,
#    'good': True,
#    'thank': True,
#    'remortgaged': True,
#    'worried': True,
#    'got': True,
#    'really': True,
#    'helpful': True,
#    'advise': True,
#    'remorgaging': True,
#    'froze': True,
#    'interest': True,
#    'rate': True},
#   '5'),
#  ({'competitive': True,
#    'rate': True,
#    'friendly': True,
#    'staff': True,
#    'fast': True,
#    'transaction': True,
#    'ease': True},
#   '5'),
#  ({'helpful': True,
#    'customer': True,
#    'service': True,
#    'competitive': True,
#    'rate': True,
#    'froze': True,
#    'interest': True},
#   '5'),
#  ({'wide': True,
#    'range': True,
#    'service': True,
#    'worried': True,
#    'got': True,
#    'really': True,
#    'helpful': True,
#    'advise': True,
#    'remorgaging': True,
#    'excellent': True,
#    'financial': True,
#    'advice': True,
#    'bad': True},
#   '5'),
#  ({'friendly': True,
#    'staff': True,
#    'ease': True,
#    'excellent': True,
#    'financial': True,
#    'advice': True,
#    'reliable': True},
#   '5'),
#  ({'stressed': True,
#    'first': True,
#    'tho': True,
#    'helpful': True,
#    'customer': True,
#    'service': True,
#    'wide': True,
#    'range': True,
#    'friendly': True,
#    'staff': True,
#    'excellent': True,
#    'financial': True,
#    'advice': True},
#   '5'),
#  ({'stressed': True,
#    'first': True,
#    'tho': True,
#    'worried': True,
#    'got': True,
#    'really': True,
#    'helpful': True,
#    'advise': True,
#    'remorgaging': True,
#    'froze': True,
#    'interest': True,
#    'rate': True,
#    'waved': True,
#    'fee': True,
#    'reliable': True},
#   '5'),
#  ({'thank': True,
#    'stressed': True,
#    'first': True,
#    'tho': True,
#    'helpful': True,
#    'customer': True,
#    'service': True,
#    'competitive': True,
#    'rate': True},
#   '5'),
#  ({'froze': True,
#    'interest': True,
#    'rate': True,
#    'reliable': True,
#    'excellent': True,
#    'financial': True,
#    'advice': True,
#    'easy': True,
#    'online': True,
#    'banking': True,
#    'wide': True,
#    'range': True,
#    'service': True,
#    'competitive': True},
#   '5'),
#  ({'helpful': True,
#    'customer': True,
#    'service': True,
#    'reliable': True,
#    'froze': True,
#    'interest': True,
#    'rate': True,
#    'bad': True,
#    'friendly': True,
#    'staff': True,
#    'thank': True},
#   '5'),
#  ({'remortgaged': True,
#    'fast': True,
#    'transaction': True,
#    'worried': True,
#    'got': True,
#    'really': True,
#    'helpful': True,
#    'advise': True,
#    'remorgaging': True,
#    'ease': True,
#    'wide': True,
#    'range': True,
#    'service': True},
#   '5'),
#  ({'reliable': True,
#    'fast': True,
#    'transaction': True,
#    'thank': True,
#    'wide': True,
#    'range': True,
#    'service': True,
#    'froze': True,
#    'interest': True,
#    'rate': True},
#   '5'),
#  ({'froze': True,
#    'interest': True,
#    'rate': True,
#    'good': True,
#    'stressed': True,
#    'first': True,
#    'tho': True,
#    'friendly': True,
#    'staff': True},
#   '5'),
#  ({'stressed': True,
#    'first': True,
#    'tho': True,
#    'bad': True,
#    'thank': True,
#    'helpful': True,
#    'customer': True,
#    'service': True,
#    'good': True,
#    'worried': True,
#    'got': True,
#    'really': True,
#    'advise': True,
#    'remorgaging': True},
#   '5'),
#  ({'thank': True,
#    'worried': True,
#    'got': True,
#    'really': True,
#    'helpful': True,
#    'advise': True,
#    'remorgaging': True,
#    'easy': True,
#    'online': True,
#    'banking': True},
#   '5'),
#  ({'stressed': True,
#    'first': True,
#    'tho': True,
#    'wide': True,
#    'range': True,
#    'service': True,
#    'fast': True,
#    'transaction': True},
#   '5'),
#  ({'bad': True,
#    'froze': True,
#    'interest': True,
#    'rate': True,
#    'ease': True,
#    'excellent': True,
#    'financial': True,
#    'advice': True},
#   '5'),
#  ({'ease': True,
#    'thank': True,
#    'remortgaged': True,
#    'good': True,
#    'fast': True,
#    'transaction': True},
#   '5'),
#  ({'thank': True,
#    'excellent': True,
#    'financial': True,
#    'advice': True,
#    'remortgaged': True,
#    'competitive': True,
#    'rate': True,
#    'stressed': True,
#    'first': True,
#    'tho': True},
#   '5'),
#  ({'helpful': True,
#    'customer': True,
#    'service': True,
#    'easy': True,
#    'online': True,
#    'banking': True,
#    'thank': True,
#    'remortgaged': True},
#   '5'),
#  ({'bad': True,
#    'reliable': True,
#    'helpful': True,
#    'customer': True,
#    'service': True,
#    'good': True,
#    'easy': True,
#    'online': True,
#    'banking': True},
#   '5'),
#  ({'fast': True,
#    'transaction': True,
#    'good': True,
#    'worried': True,
#    'got': True,
#    'really': True,
#    'helpful': True,
#    'advise': True,
#    'remorgaging': True,
#    'friendly': True,
#    'staff': True,
#    'easy': True,
#    'online': True,
#    'banking': True},
#   '5'),
#  ({'ease': True,
#    'fast': True,
#    'transaction': True,
#    'friendly': True,
#    'staff': True,
#    'waved': True,
#    'fee': True,
#    'competitive': True,
#    'rate': True},
#   '5'),
#  ({'remortgaged': True,
#    'easy': True,
#    'online': True,
#    'banking': True,
#    'ease': True,
#    'competitive': True,
#    'rate': True,
#    'worried': True,
#    'got': True,
#    'really': True,
#    'helpful': True,
#    'advise': True,
#    'remorgaging': True},
#   '5'),
#  ({'easy': True,
#    'online': True,
#    'banking': True,
#    'thank': True,
#    'stressed': True,
#    'first': True,
#    'tho': True,
#    'helpful': True,
#    'customer': True,
#    'service': True},
#   '5'),
#  ({'remortgaged': True,
#    'stressed': True,
#    'first': True,
#    'tho': True,
#    'worried': True,
#    'got': True,
#    'really': True,
#    'helpful': True,
#    'advise': True,
#    'remorgaging': True},
#   '5'),
#  ({'bad': True,
#    'helpful': True,
#    'customer': True,
#    'service': True,
#    'good': True},
#   '5'),
#  ({'easy': True,
#    'online': True,
#    'banking': True,
#    'competitive': True,
#    'rate': True,
#    'remortgaged': True,
#    'wide': True,
#    'range': True,
#    'service': True,
#    'stressed': True,
#    'first': True,
#    'tho': True},
#   '5'),
#  ({'helpful': True,
#    'customer': True,
#    'service': True,
#    'worried': True,
#    'got': True,
#    'really': True,
#    'advise': True,
#    'remorgaging': True,
#    'wide': True,
#    'range': True,
#    'fast': True,
#    'transaction': True,
#    'stressed': True,
#    'first': True,
#    'tho': True,
#    'reliable': True},
#   '5'),
#  ({'good': True,
#    'thank': True,
#    'helpful': True,
#    'customer': True,
#    'service': True,
#    'friendly': True,
#    'staff': True,
#    'waved': True,
#    'fee': True,
#    'remortgaged': True},
#   '5'),
#  ({'fast': True,
#    'transaction': True,
#    'waved': True,
#    'fee': True,
#    'froze': True,
#    'interest': True,
#    'rate': True,
#    'bad': True},
#   '5'),
#  ({'worried': True,
#    'got': True,
#    'really': True,
#    'helpful': True,
#    'advise': True,
#    'remorgaging': True,
#    'ease': True,
#    'froze': True,
#    'interest': True,
#    'rate': True,
#    'reliable': True,
#    'stressed': True,
#    'first': True,
#    'tho': True},
#   '5'),
#  ({'ease': True,
#    'excellent': True,
#    'financial': True,
#    'advice': True,
#    'reliable': True,
#    'competitive': True,
#    'rate': True,
#    'helpful': True,
#    'customer': True,
#    'service': True},
#   '5'),
#  ...]

# %%
import nltk.classify
# Split the data
mort_train_data, mort_test_data = train_test_split(mort_data, test_size=0.25, random_state=42)

# Train the classifier
mort_clf = NaiveBayesClassifier.train(mort_train_data)

print("Classifier accuracy percent:",(nltk.classify.accuracy(mort_clf, mort_test_data))*100)
# Out:
# Classifier accuracy percent: 100.0

# %%
from sklearn.metrics import confusion_matrix

mort_test_actual = [label for _, label in mort_test_data]
mort_test_pred = [mort_clf.classify(features) for features, _ in mort_test_data]

# Generate the confusion matrix using sklearn
mort_cm = confusion_matrix(mort_test_actual, mort_test_pred)


# You might need to explicitly define your labels
mortlabels = sorted(set(mort_test_actual))  # Sort labels if necessary

mort_cm_df = pd.DataFrame(mort_cm, index=mortlabels, columns=mortlabels)

# %%
mort_cm_df
# Out:
#      1    5
# 1  182    0
# 5    0  193

# %%
mort_accuracy = accuracy_score(mort_test_actual, mort_test_pred)
print(f"Accuracy: {mort_accuracy:.2f}")



mort_report = classification_report(mort_test_actual, mort_test_pred)
print(mort_report)
# Out:
# Accuracy: 1.00
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       182
#            5       1.00      1.00      1.00       193
#
#     accuracy                           1.00       375
#    macro avg       1.00      1.00      1.00       375
# weighted avg       1.00      1.00      1.00       375

# %%
# Show the most informative features
mort_informative_features =mort_clf.show_most_informative_features(100)
# Out:
# Most Informative Features
#                  helpful = None                1 : 5      =      2.0 : 1.0
#                     rate = True                5 : 1      =      1.9 : 1.0
#                      fee = True                1 : 5      =      1.6 : 1.0
#                     rate = None                1 : 5      =      1.5 : 1.0
#                    range = None                1 : 5      =      1.4 : 1.0
#                     wide = None                1 : 5      =      1.4 : 1.0
#                     fast = None                1 : 5      =      1.4 : 1.0
#              competitive = None                1 : 5      =      1.4 : 1.0
#                     good = None                1 : 5      =      1.4 : 1.0
#                    froze = None                1 : 5      =      1.4 : 1.0
#                      mum = None                5 : 1      =      1.4 : 1.0
#                    thank = None                1 : 5      =      1.4 : 1.0
#                 reliable = None                1 : 5      =      1.4 : 1.0
#                    waved = None                1 : 5      =      1.4 : 1.0
#                   advise = None                1 : 5      =      1.4 : 1.0
#                      got = None                1 : 5      =      1.4 : 1.0
#                   really = None                1 : 5      =      1.4 : 1.0
#              remorgaging = None                1 : 5      =      1.4 : 1.0
#                  worried = None                1 : 5      =      1.4 : 1.0
#                     slow = None                5 : 1      =      1.4 : 1.0
#                     long = None                5 : 1      =      1.4 : 1.0
#                     time = None                5 : 1      =      1.4 : 1.0
#                     wait = None                5 : 1      =      1.4 : 1.0
#                   rising = None                5 : 1      =      1.4 : 1.0
#                    first = None                1 : 5      =      1.4 : 1.0
#                 friendly = None                1 : 5      =      1.4 : 1.0
#                 stressed = None                1 : 5      =      1.4 : 1.0
#                      tho = None                1 : 5      =      1.4 : 1.0
#                     ease = None                1 : 5      =      1.4 : 1.0
#                    great = None                5 : 1      =      1.4 : 1.0
#                     poor = None                5 : 1      =      1.4 : 1.0
#               additional = None                5 : 1      =      1.4 : 1.0
#                   charge = None                5 : 1      =      1.4 : 1.0
#                  limited = None                5 : 1      =      1.4 : 1.0
#                     high = None                5 : 1      =      1.4 : 1.0
#               distressed = None                5 : 1      =      1.4 : 1.0
#                 happened = None                5 : 1      =      1.4 : 1.0
#                 insecure = None                5 : 1      =      1.4 : 1.0
#                  banking = None                1 : 5      =      1.4 : 1.0
#                     easy = None                1 : 5      =      1.4 : 1.0
#                   online = None                1 : 5      =      1.4 : 1.0
#                     hope = None                5 : 1      =      1.4 : 1.0
#                    proud = None                5 : 1      =      1.4 : 1.0
#                    youre = None                5 : 1      =      1.4 : 1.0
#                unhelpful = None                5 : 1      =      1.3 : 1.0
#                     rude = None                5 : 1      =      1.3 : 1.0
#                excellent = None                1 : 5      =      1.3 : 1.0
#                  manager = None                5 : 1      =      1.3 : 1.0
#                 terrible = None                5 : 1      =      1.3 : 1.0
#              remortgaged = None                1 : 5      =      1.3 : 1.0
#                      fee = None                5 : 1      =      1.3 : 1.0
#                 customer = True                5 : 1      =      1.1 : 1.0
#                 interest = True                5 : 1      =      1.1 : 1.0
#                   advice = True                1 : 5      =      1.1 : 1.0
#                financial = True                1 : 5      =      1.1 : 1.0
#                      bad = True                5 : 1      =      1.1 : 1.0
#                  service = True                5 : 1      =      1.1 : 1.0
#              transaction = True                5 : 1      =      1.1 : 1.0
#                  service = None                1 : 5      =      1.1 : 1.0
#                    staff = True                5 : 1      =      1.1 : 1.0
#                 customer = None                1 : 5      =      1.0 : 1.0
#                 interest = None                1 : 5      =      1.0 : 1.0
#                      bad = None                1 : 5      =      1.0 : 1.0
#                   advice = None                5 : 1      =      1.0 : 1.0
#                financial = None                5 : 1      =      1.0 : 1.0
#              transaction = None                1 : 5      =      1.0 : 1.0
#                    staff = None                1 : 5      =      1.0 : 1.0

# %% [markdown]
# ## Testing the Model

# %%
def simple_preprocess_and_features(text):
    # Tokenize the text
    tokens = word_tokenize(text.lower())  # Lowercasing and tokenizing
    # Convert tokens to a feature dictionary
    features = {word: True for word in tokens}
    return features

# %% [markdown]
# ### Mortgage

# %%
# Positive Review - Mortgage
new_text = "Smooth mortgage process with excellent customer service, making my dream home purchase a reality."

# Preprocess the text and extract features
features = simple_preprocess_and_features(new_text)

# Use the classifier to predict
predicted_label = mort_clf.classify(features)
print(f"Predicted label: {predicted_label}")

# Get the probability distribution
prob_dist = mort_clf.prob_classify(features)
print(f"Probabilities:")
for label in mort_clf.labels():
    print(f"{label}: {prob_dist.prob(label):.4f}")
# Out:
# Predicted label: 5
# Probabilities:
# 5: 0.9971
# 1: 0.0029

# %%
# Positive Review - Mortgage
new_text = "Competitive interest rates and flexible repayment options, allowing me to save significantly on my home loan."

# Preprocess the text and extract features
features = simple_preprocess_and_features(new_text)

# Use the classifier to predict
predicted_label = mort_clf.classify(features)
print(f"Predicted label: {predicted_label}")

# Get the probability distribution
prob_dist = mort_clf.prob_classify(features)
print(f"Probabilities:")
for label in mort_clf.labels():
    print(f"{label}: {prob_dist.prob(label):.4f}")
# Out:
# Predicted label: 5
# Probabilities:
# 5: 0.9973
# 1: 0.0027

# %%
# Negative Review - Mortgage
new_text = "Constant delays and miscommunication throughout the mortgage application, causing frustration and anxiety."

# Preprocess the text and extract features
features = simple_preprocess_and_features(new_text)

# Use the classifier to predict
predicted_label = mort_clf.classify(features)
print(f"Predicted label: {predicted_label}")

# Get the probability distribution
prob_dist = mort_clf.prob_classify(features)
print(f"Probabilities:")
for label in mort_clf.labels():
    print(f"{label}: {prob_dist.prob(label):.4f}")
# Out:
# Predicted label: 1
# Probabilities:
# 5: 0.4951
# 1: 0.5049

# %%
# Negative Review - Mortgage
new_text = "Hidden fees and unexpected charges added to the mortgage agreement, leading to unexpected financial burden."

# Preprocess the text and extract features
features = simple_preprocess_and_features(new_text)

# Use the classifier to predict
predicted_label = mort_clf.classify(features)
print(f"Predicted label: {predicted_label}")

# Get the probability distribution
prob_dist = mort_clf.prob_classify(features)
print(f"Probabilities:")
for label in mort_clf.labels():
    print(f"{label}: {prob_dist.prob(label):.4f}")
# Out:
# Predicted label: 1
# Probabilities:
# 5: 0.4734
# 1: 0.5266

# %%
# Complex Postive Review - Mortgage
new_text = "Despite initial apprehensions, the mortgage process proved surprisingly efficient with personalised guidance, though the lack of transparency regarding fluctuating interest rates posed challenges for long-term financial planning."

# Preprocess the text and extract features
features = simple_preprocess_and_features(new_text)

# Use the classifier to predict
predicted_label = mort_clf.classify(features)
print(f"Predicted label: {predicted_label}")

# Get the probability distribution
prob_dist = mort_clf.prob_classify(features)
print(f"Probabilities:")
for label in mort_clf.labels():
    print(f"{label}: {prob_dist.prob(label):.4f}")
# Out:
# Predicted label: 1
# Probabilities:
# 5: 0.4970
# 1: 0.5030

# %%
# Neutral Review - Mortgage
new_text = "The mortgage application process was standard, with satisfactory rates and terms, although the absence of comprehensive financial education resources left room for improvement in empowering borrowers to make informed decisions."

# Preprocess the text and extract features
features = simple_preprocess_and_features(new_text)

# Use the classifier to predict
predicted_label = mort_clf.classify(features)
print(f"Predicted label: {predicted_label}")

# Get the probability distribution
prob_dist = mort_clf.prob_classify(features)
print(f"Probabilities:")
for label in mort_clf.labels():
    print(f"{label}: {prob_dist.prob(label):.4f}")
# Out:
# Predicted label: 1
# Probabilities:
# 5: 0.4734
# 1: 0.5266

# %% [markdown]
# ### Online Services

# %%
# Positive Review - Online Services
new_text = "Convenient online banking platform with user-friendly interface, making managing finances hassle-free."

# Preprocess the text and extract features
features = simple_preprocess_and_features(new_text)

# Use the classifier to predict
predicted_label = OS_clf.classify(features)
print(f"Predicted label: {predicted_label}")

# Get the probability distribution
prob_dist = OS_clf.prob_classify(features)
print(f"Probabilities:")
for label in OS_clf.labels():
    print(f"{label}: {prob_dist.prob(label):.4f}")
# Out:
# Predicted label: 5
# Probabilities:
# 5: 0.6197
# 1: 0.3803

# %%
# Negative Review - Online Services
new_text = "Frequent technical glitches and slow response times on the mobile app, hindering banking transactions."

# Preprocess the text and extract features
features = simple_preprocess_and_features(new_text)

# Use the classifier to predict
predicted_label = OS_clf.classify(features)
print(f"Predicted label: {predicted_label}")

# Get the probability distribution
prob_dist = OS_clf.prob_classify(features)
print(f"Probabilities:")
for label in OS_clf.labels():
    print(f"{label}: {prob_dist.prob(label):.4f}")
# Out:
# Predicted label: 1
# Probabilities:
# 5: 0.0006
# 1: 0.9994

# %%
# Complex Negative Review - Online Services
new_text = "While the online banking platform boasted advanced security features, the complex authentication procedures and limited customer support channels made resolving issues a cumbersome ordeal, overshadowing its convenience."

# Preprocess the text and extract features
features = simple_preprocess_and_features(new_text)

# Use the classifier to predict
predicted_label = OS_clf.classify(features)
print(f"Predicted label: {predicted_label}")

# Get the probability distribution
prob_dist = OS_clf.prob_classify(features)
print(f"Probabilities:")
for label in OS_clf.labels():
    print(f"{label}: {prob_dist.prob(label):.4f}")
# Out:
# Predicted label: 1
# Probabilities:
# 5: 0.0009
# 1: 0.9991

# %%
# Neutral Review - Online Services
new_text = "The online banking experience offered a balance of convenience and security, yet the interface design lacked innovation, presenting a functional but unremarkable user journey for everyday transactions."

# Preprocess the text and extract features
features = simple_preprocess_and_features(new_text)

# Use the classifier to predict
predicted_label = OS_clf.classify(features)
print(f"Predicted label: {predicted_label}")

# Get the probability distribution
prob_dist = OS_clf.prob_classify(features)
print(f"Probabilities:")
for label in OS_clf.labels():
    print(f"{label}: {prob_dist.prob(label):.4f}")
# Out:
# Predicted label: 5
# Probabilities:
# 5: 0.6197
# 1: 0.3803

# %% [markdown]
# ## Attempting to create a filter

# %%
def simple_preprocess_and_features(text):
    # Tokenize the text
    tokens = word_tokenize(text.lower())  # Lowercasing and tokenizing
    # Convert tokens to a feature dictionary
    features = {word: True for word in tokens}
    return features

features = simple_preprocess_and_features(text)

# %%
online_model = OS_clf
mortgage_model = mort_clf

def classify_post(text, online_model, mortgage_model):
     # Use the appropriate classifier to predict
    if 'online' in text.lower():
        predicted_label = online_model.classify(features)
        prob_dist = online_model.prob_classify(features)
        pred_source = 'Online'
    elif 'mortgage' in text.lower() or 'home' in text.lower():
        predicted_label = mortgage_model.classify(features)
        prob_dist = mortgage_model.prob_classify(features)
        pred_source = 'Mortgage'
    else:
        return 'Unknown'

    # Return the predicted label and probability distribution
    return predicted_label, prob_dist, pred_source

text = 'I had a great experience with the online service.'

predicted_label, prob_dist, pred_source = classify_post(text, online_model, mortgage_model)

# Output the results
print('Type: ', pred_source)
print('Predicted label:', predicted_label)
print('Probability distribution:')
for label in prob_dist.samples():
    print(f"{label}: {prob_dist.prob(label):.4f}")
# Out:
# Type:  Online
# Predicted label: 5
# Probability distribution:
# 5: 0.9997
# 1: 0.0003

# %%
online_model = OS_clf
mortgage_model = mort_clf

def classify_post(text, online_model, mortgage_model):
     # Use the appropriate classifier to predict
    if 'online' in text.lower():
        predicted_label = online_model.classify(features)
        prob_dist = online_model.prob_classify(features)
        pred_source = 'Online'
    elif 'mortgage' in text.lower() or 'home' in text.lower():
        predicted_label = mortgage_model.classify(features)
        prob_dist = mortgage_model.prob_classify(features)
        pred_source = 'Mortgage'
    else:
        return 'Unknown'

    # Return the predicted label and probability distribution
    return predicted_label, prob_dist, pred_source

text = 'Using online services for financial matters has been disappointing lately, encountering frequent technical issues and sluggish response times.'
 
predicted_label, prob_dist, pred_source = classify_post(text, online_model, mortgage_model)

# Output the results
print('Type: ', pred_source)
print('Predicted label:', predicted_label)
print('Probability distribution:')
for label in prob_dist.samples():
    print(f"{label}: {prob_dist.prob(label):.4f}")
# Out:
# Type:  Online
# Predicted label: 5
# Probability distribution:
# 5: 0.9997
# 1: 0.0003

# %%
online_model = OS_clf
mortgage_model = mort_clf

def classify_post(text, online_model, mortgage_model):
     # Use the appropriate classifier to predict
    if 'online' in text.lower():
        predicted_label = online_model.classify(features)
        prob_dist = online_model.prob_classify(features)
        pred_source = 'Online'
    elif 'mortgage' in text.lower() or 'home' in text.lower():
        predicted_label = mortgage_model.classify(features)
        prob_dist = mortgage_model.prob_classify(features)
        pred_source = 'Mortgage'
    else:
        return 'Unknown'

    # Return the predicted label and probability distribution
    return predicted_label, prob_dist, pred_source

text = 'Competitive interest rates and flexible repayment options, allowing me to save significantly on my home loan.'
 
online_model = OS_clf
mortgage_model = mort_clf
predicted_label, prob_dist, pred_source = classify_post(text, online_model, mortgage_model)

# Output the results
print('Type: ', pred_source)
print('Predicted label:', predicted_label)
print('Probability distribution:')
for label in prob_dist.samples():
    print(f"{label}: {prob_dist.prob(label):.4f}")
# Out:
# Type:  Mortgage
# Predicted label: 5
# Probability distribution:
# 5: 0.9973
# 1: 0.0027
