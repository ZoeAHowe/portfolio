# %%
import pandas as pd

# %%
df = {
    'Type of Model': ['Initial Decision Tree', 'SMOTE with a depth of 4', 'SMOTE with a depth of 2', 'Random Oversampling', 'ADASYN', 'BorderlineSMOTE', 'SMOTEENN', 'Specifying Columns', 'Specifying Columns SMOTE', 'Random Forest', 'Random Forest 2', 'Naive Bayes', 'Naive Bayes 2', 'Deep Learning'],
    'Accuracy': ['0.8904124737365918','0.802056839544399','0.6545394227579343','0.7475395333407056','0.8036049983412584','0.8051531571381179','0.7877916620590512','0.8901913081941834','0.7197832577684397','0.891850049762247','0.891850049762247','0.816874930885768','0.834347008736039','0.891960620880127'],
    'Precision': ['0.6785714285714286','0.3067993366500829','0.19428571428571428','0.25573770491803277','0.2986478542034098','0.30183106910809215','0.28210526315789475','0.7024793388429752','0.20610997963340122','0.6416040100250626','0.6416040100250626','0.30313588850174217','0.35658914728682173','0.7723908329599021'],
    'Recall': ['0.17415215398716777', '0.5087076076993584', '0.5921173235563703', '0.5719523373052245', '0.46562786434463793', '0.46837763519706693', '0.4912923923006416', '0.15582034830430797', '0.46379468377635197', '0.23464711274060496', '0.23464711274060496', '0.3987167736021998', '0.46379468377635197', '0.609581238577201']
}

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#                Type of Model            Accuracy            Precision  \
# 0      Initial Decision Tree  0.8904124737365918   0.6785714285714286
# 1    SMOTE with a depth of 4   0.802056839544399   0.3067993366500829
# 2    SMOTE with a depth of 2  0.6545394227579343  0.19428571428571428
# 3        Random Oversampling  0.7475395333407056  0.25573770491803277
# 4                     ADASYN  0.8036049983412584   0.2986478542034098
# 5            BorderlineSMOTE  0.8051531571381179  0.30183106910809215
# 6                   SMOTEENN  0.7877916620590512  0.28210526315789475
# 7         Specifying Columns  0.8901913081941834   0.7024793388429752
# 8   Specifying Columns SMOTE  0.7197832577684397  0.20610997963340122
# 9              Random Forest   0.891850049762247   0.6416040100250626
# 10           Random Forest 2   0.891850049762247   0.6416040100250626
# 11               Naive Bayes   0.816874930885768  0.30313588850174217
# ...

# %%
df.dtypes
# Out:
# Type of Model    object
# Accuracy         object
# Precision        object
# Recall           object
# dtype: object

# %%
df[['Accuracy', 'Precision', 'Recall']] = df[['Accuracy', 'Precision', 'Recall']].astype('float')

# %%
df = df.round(2)

# %%
df = df.sort_values(['Recall'], ascending=False)

# %%
Types_of_Model = df

# %%
Types_of_Model.to_csv('Types_of_Model.csv')

# %%
Types_of_Model
# Out:
#                Type of Model  Accuracy  Precision  Recall
# 13             Deep Learning      0.89       0.77    0.61
# 2    SMOTE with a depth of 2      0.65       0.19    0.59
# 3        Random Oversampling      0.75       0.26    0.57
# 1    SMOTE with a depth of 4      0.80       0.31    0.51
# 6                   SMOTEENN      0.79       0.28    0.49
# 4                     ADASYN      0.80       0.30    0.47
# 5            BorderlineSMOTE      0.81       0.30    0.47
# 8   Specifying Columns SMOTE      0.72       0.21    0.46
# 12             Naive Bayes 2      0.83       0.36    0.46
# 11               Naive Bayes      0.82       0.30    0.40
# 9              Random Forest      0.89       0.64    0.23
# 10           Random Forest 2      0.89       0.64    0.23
# 0      Initial Decision Tree      0.89       0.68    0.17
# 7         Specifying Columns      0.89       0.70    0.16
